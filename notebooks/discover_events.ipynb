# %%
import csv
import json
import random
import jsonlines
import collections
import numpy as np

from glob import glob
from tqdm import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# # Collect count stats

# %% [markdown]
# ## For all docs

# %%
all_preds_args_cntr = collections.Counter()
all_preds_cntr = collections.Counter()

for pred_arg_path in tqdm(glob('../data/cgw/preds_args/*.jsonl')):
    with jsonlines.open(pred_arg_path) as reader:
        for doc in reader:
            assert doc['filename'].endswith('.comm')
            doc_id = doc['filename'][:-5]
            preds_args = [(a0.lower(), a1.lower(), ix) for (a0, a1, ix) in doc['preds_args']]
            doc_preds_args = [f'{a0}_{a1}_{ix}' for a0, a1, ix in preds_args]
            doc_preds = [(a0 if ix == 0 else a1) for a0, a1, ix in preds_args]
            all_preds_args_cntr.update(doc_preds_args)
            all_preds_cntr.update(doc_preds)
# Out:
# 100%|██████████| 197/197 [04:52<00:00,  1.48s/it]

# %% [markdown]
# ## For schema related docs

# %%
schema_name = 'election'

# Collect the ids of schema relevant docs

schema_related_docs_ids = set()

with jsonlines.open(f'../data/cgw/schema_related/pos/{schema_name}.jsonl') as reader:
    for doc in reader:
        schema_related_docs_ids.add(doc['id'])

# %%
schema_preds_args_cntr = collections.Counter()
schema_preds_cntr = collections.Counter()

for pred_arg_path in tqdm(glob('../data/cgw/preds_args/*.jsonl')):
    with jsonlines.open(pred_arg_path) as reader:
        for doc in reader:
            assert doc['filename'].endswith('.comm')
            doc_id = doc['filename'][:-5]
            if doc_id in schema_related_docs_ids:
                preds_args = [(a0.lower(), a1.lower(), ix) for (a0, a1, ix) in doc['preds_args']]
                doc_preds_args = [f'{a0}_{a1}_{ix}' for a0, a1, ix in preds_args]
                doc_preds = [(a0 if ix == 0 else a1) for a0, a1, ix in preds_args]
                schema_preds_args_cntr.update(doc_preds_args)
                schema_preds_cntr.update(doc_preds)
# Out:
# 100%|██████████| 197/197 [01:08<00:00,  2.86it/s]

# %% [markdown]
# # Discover schema related events

# %%
z_all = sum(v for v in all_preds_cntr.values())
z_schema = sum(v for v in schema_preds_cntr.values())

schema_top_preds = [k for k, v in schema_preds_cntr.items() if v >= 100]
schema_top_preds_rates = [(k, (schema_preds_cntr[k] / z_schema) / (all_preds_cntr[k] / z_all)) for k in schema_top_preds]
schema_top_preds_rates = [(k, v) for k, v in schema_top_preds_rates if v > 1]
schema_top_preds_rates.sort(key=lambda x: -x[1])

# %%
# TODO: make sure the selected pred-only events typically expect similar types of args; that an event does not conflate multiple args

# %%
print(len(schema_top_preds_rates))
# Out:
# 710

# %%
schema_top_preds_rates
# Out:
# [('voter', 36.35676704731012),
#  ('election', 36.296766938715294),
#  ('elect', 27.218845134364706),
#  ('disenfranchise', 21.786111604650532),
#  ('elected', 16.412711988050173),
#  ('outspent', 14.790466055812104),
#  ('unseated', 14.529726697755576),
#  ('candidate', 14.449733668279983),
#  ('democratic', 13.017742505574814),
#  ('vote', 11.932886370967145),
#  ('undecided', 11.739155350931489),
#  ('democrats', 11.566640588198213),
#  ('republican', 10.82555870220436),
#  ('republicans', 9.877199316117094),
#  ('democrat', 9.301091124691375),
#  ('nominee', 9.27133760880697),
#  ('campaign', 9.213812169607703),
#  ('unseat', 8.728223590213258),
#  ('campaigning', 8.493878784218463),
#  ('boycott', 8.001994530854793),
#  ('governor', 7.936002773489225),
#  ('mayor', 7.4758093563552),
#  ('senator', 7.044897425075981),
#  ('poll', 6.965648171817239),
#  ('re-elected', 6.681994613003907),
#  ('cast', 6.666003030888622),
#  ('energize', 6.630760227558706),
#  ('trounce', 6.462291726602186),
#  ('dissent', 6.423548970447496),
#  ('contest', 6.380948456195358),
#  ('liberal', 6.217084644872886),
#  ('endorse', 6.127157127966643),
#  ('nominate', 6.106330890865254),
#  ('retake', 5.955399641136677),
#  ('politician', 5.867814187600661),
#  ('conservative', 5.6319474655652675),
#  ('alienate', 5.620537937201227),
#  ('polarize', 5.516491459037634),
#  ('register', 5.300634214879146),
#  ('siphon', 5.218179923736447),
#  ('mobilize', 5.215488528534543),
#  ('galvanize', 5.124042819190216),
#  ('defeat', 5.120592077640349),
#  ('oust', 5.060126103634789),
#  ('court', 5.03121403704021),
#  ('invalidate', 5.028820198711763),
#  ('party', 4.940536836495227),
#  ('unpopular', 4.938006219022491),
#  ('woo', 4.791258288343407),
#  ('disqualify', 4.765727517706767),
#  ('independent', 4.709141019973114),
#  ('republish', 4.6405318691922135),
#  ('congratulate', 4.469995417579443),
#  ('speaker', 4.293890108340038),
#  ('sway', 4.220717524026684),
#  ('impeach', 4.160317787058621),
#  ('certify', 4.057214772893977),
#  ('unite', 4.043329441026561),
#  ('back', 3.9822826263615148),
#  ('supporter', 3.9759514641672236),
#  ('moderate', 3.9752015094601787),
#  ('outnumber', 3.9351570894263053),
#  ('favor', 3.9211761303577686),
#  ('crisscross', 3.825104201336944),
#  ('corrupt', 3.6160713516201706),
#  ('garner', 3.561012062812503),
#  ('tally', 3.551175953469673),
#  ('politics', 3.536730491964033),
#  ('tilt', 3.5344886679495793),
#  ('recount', 3.492339510995842),
#  ('support', 3.467600817368113),
#  ('privatize', 3.440848415552053),
#  ('minister', 3.419347217363978),
#  ('reform', 3.399058114910425),
#  ('wins', 3.39404740121492),
#  ('appoint', 3.381038177343833),
#  ('govern', 3.3478596909745044),
#  ('espouse', 3.284923610620955),
#  ('triumph', 3.245401885715064),
#  ('oppose', 3.2244262664604197),
#  ('backfire', 3.1999602858561356),
#  ('wag', 3.185987870113403),
#  ('overturn', 3.180829396370173),
#  ('abolish', 3.1278563870350045),
#  ('assail', 3.1137844336036613),
#  ('resonate', 3.0812209601581633),
#  ('black', 3.049760821510626),
#  ('deride', 3.036360992313993),
#  ('bash', 2.989777143878099),
#  ('win', 2.963173526761139),
#  ('run', 2.9415852013069896),
#  ('align', 2.901280044617601),
#  ('denounce', 2.870750666250835),
#  ('implore', 2.8567669023316564),
#  ('fend', 2.855119223860503),
#  ('count', 2.8131522695479227),
#  ('distance', 2.8068770648416175),
#  ('tout', 2.7928473784554333),
#  ('empower', 2.7556094134093607),
#  ('prevail', 2.7547637395440674),
#  ('chant', 2.7473893659986914),
#  ('cede', 2.7431313171983884),
#  ('secretary', 2.7409849419531),
#  ('victory', 2.711392644318767),
#  ('unconstitutional', 2.7084966548122944),
#  ('vie', 2.7077693060009174),
#  ('concede', 2.707214751432498),
#  ('vow', 2.695883674572738),
#  ('mail', 2.693858094822551),
#  ('intimidate', 2.688529234372723),
#  ('uphold', 2.6653990620023325),
#  ('distort', 2.6092836438489124),
#  ('swing', 2.5906764203459396),
#  ('challenge', 2.5879645839902006),
#  ('ridicule', 2.582700693674478),
#  ('president', 2.574729851634803),
#  ('ally', 2.5534402050312934),
#  ('advocate', 2.525038629805868),
#  ('split', 2.5119934293222075),
#  ('muster', 2.5114855613412947),
#  ('reclaim', 2.4913010812019767),
#  ('select', 2.4905762703125),
#  ('citizen', 2.460429270247505),
#  ('declare', 2.4564534278252212),
#  ('articulate', 2.454212003027039),
#  ('debate', 2.447770731287048),
#  ('state', 2.4444251245026747),
#  ('mock', 2.441116225989062),
#  ('lean', 2.4402674820439816),
#  ('motivate', 2.4365371713946598),
#  ('message', 2.4135238269145898),
#  ('pledge', 2.4132026077724715),
#  ('amend', 2.4109236796119187),
#  ('legalize', 2.4091945708276583),
#  ('pit', 2.361983407043788),
#  ('resign', 2.358517176994205),
#  ('contrast', 2.3526787418430777),
#  ('repeal', 2.3515644437642065),
#  ('trail', 2.3513908425196592),
#  ('trump', 2.3388895797170877),
#  ('field', 2.332353336050924),
#  ('infuriate', 2.326530498141821),
#  ('buck', 2.319928494599228),
#  ('accuse', 2.315530868261919),
#  ('defy', 2.291981058660304),
#  ('punch', 2.291616021441767),
#  ('dissolve', 2.2904398834554196),
#  ('swamp', 2.2805499303363894),
#  ('overshadow', 2.280333173778914),
#  ('leader', 2.2784951828684403),
#  ('influence', 2.2627045841575195),
#  ('factor', 2.2550379826336386),
#  ('counter', 2.2510229663717216),
#  ('convene', 2.25043851358129),
#  ('crucial', 2.2448570377742656),
#  ('prohibitive', 2.2209632404185515),
#  ('stake', 2.2054516507752537),
#  ('reject', 2.2032703581122406),
#  ('criticize', 2.2029220535732543),
#  ('solidify', 2.1946778279952026),
#  ('urge', 2.1891076069493085),
#  ('strategy', 2.180767885765369),
#  ('attack', 2.1788228461022925),
#  ('downplay', 2.1737199613612512),
#  ('choose', 2.171104576465104),
#  ('decry', 2.160892624368112),
#  ('position', 2.1585522932140493),
#  ('divide', 2.1505985109044716),
#  ('side', 2.144492391988654),
#  ('rewrite', 2.143678277032484),
#  ('promise', 2.1435928433031517),
#  ('succeed', 2.135380726838096),
#  ('white', 2.135054592707136),
#  ('scoff', 2.128716621835158),
#  ('override', 2.1235898964650013),
#  ('engineer', 2.120578376296264),
#  ('tip', 2.116209565717137),
#  ('dominate', 2.0947737479975523),
#  ('portray', 2.093433049322258),
#  ('propel', 2.089264316701717),
#  ('dislike', 2.077075714994999),
#  ('mount', 2.0748843797528),
#  ('champion', 2.070349904463702),
#  ('ratify', 2.067841469116472),
#  ('dismiss', 2.0637857698939137),
#  ('regain', 2.0539480778260386),
#  ('topple', 2.0506633746146945),
#  ('outlaw', 2.0186061320042072),
#  ('anger', 2.0076022221386483),
#  ('chair', 2.0042143654529396),
#  ('sweep', 2.0005568906344893),
#  ('cap', 1.9865178231164067),
#  ('contributed', 1.986160749220681),
#  ('stun', 1.982185240857366),
#  ('edge', 1.9742756301152662),
#  ('popular', 1.973258008378738),
#  ('faces', 1.9697179508982254),
#  ('underscore', 1.9620095740864378),
#  ('predict', 1.9478104903897522),
#  ('organize', 1.9428718281571946),
#  ('overhaul', 1.9410592192128437),
#  ('differ', 1.9300005385142638),
#  ('offend', 1.9285011910903684),
#  ('undermine', 1.9247917218438269),
#  ('ban', 1.920187668472054),
#  ('trust', 1.9192368179623953),
#  ('dispatch', 1.9191293598118717),
#  ('target', 1.9183126131042574),
#  ('veto', 1.914582659077174),
#  ('confuse', 1.9121406664207212),
#  ('emphasize', 1.9027231396457338),
#  ('hail', 1.8999229349210907),
#  ('enact', 1.8958652283428916),
#  ('dilute', 1.8709835310309944),
#  ('spearhead', 1.8630983156309207),
#  ('critical', 1.8616107955818284),
#  ('complicate', 1.8587990618708508),
#  ('choice', 1.8563045665670876),
#  ('withdraw', 1.8544833882454872),
#  ('control', 1.8534398446246758),
#  ('angry', 1.842991950751368),
#  ('rally', 1.8345410763929861),
#  ('rule', 1.830383849891696),
#  ('exit', 1.83029888920497),
#  ('chief', 1.8287618755990451),
#  ('frame', 1.82456577465591),
#  ('amass', 1.824419143923158),
#  ('judge', 1.8185216784516651),
#  ('draw', 1.8155288963275427),
#  ('hold', 1.8141928309054134),
#  ('disagree', 1.7960322064226069),
#  ('shape', 1.7936204098880721),
#  ('shore', 1.7884097119765439),
#  ('appeal', 1.7796626140466756),
#  ('recruit', 1.7792436877807474),
#  ('cripple', 1.774450765254644),
#  ('scare', 1.7701529069083064),
#  ('unhappy', 1.7691941240203397),
#  ('wield', 1.7623876857462564),
#  ('praise', 1.7569448282622273),
#  ('determine', 1.745063515510204),
#  ('capture', 1.7447657497178912),
#  ('view', 1.7278856633064092),
#  ('hammer', 1.7249723430951591),
#  ('switch', 1.724962476686915),
#  ('mislead', 1.722312932210114),
#  ('woman', 1.7218379999923086),
#  ('preside', 1.719466414679404),
#  ('stress', 1.7156438141141306),
#  ('discourage', 1.712871757184379),
#  ('bar', 1.7066918488914264),
#  ('vulnerable', 1.704419337840433),
#  ('competitive', 1.6999512095397398),
#  ('legal', 1.6972067668103303),
#  ('face', 1.6951058899495792),
#  ('educate', 1.6924138042242396),
#  ('emerge', 1.6919635828128972),
#  ('deprive', 1.6886869167717695),
#  ('blast', 1.688436825300455),
#  ('squander', 1.687832745471734),
#  ('abandon', 1.6844860780253543),
#  ('seek', 1.6834475384847096),
#  ('show', 1.6824113163495469),
#  ('fair', 1.6629935386685137),
#  ('grip', 1.6567286509478398),
#  ('demonstrate', 1.6556973251171938),
#  ('unknown', 1.6545740981361245),
#  ('country', 1.6531589444549486),
#  ('unleash', 1.6502055593722667),
#  ('group', 1.6487968698891955),
#  ('unfair', 1.6487815384398599),
#  ('relinquish', 1.6466458020690284),
#  ('postpone', 1.6459650765897391),
#  ('assert', 1.6402101588999658),
#  ('supervise', 1.6387140464265078),
#  ('convince', 1.6362778053362568),
#  ('hand', 1.629166723960587),
#  ('intend', 1.6290105088146312),
#  ('funnel', 1.6271224372551707),
#  ('argue', 1.6268907794606053),
#  ('confident', 1.6244999518928205),
#  ('clash', 1.6236483914365862),
#  ('allocate', 1.6235093681060222),
#  ('pressure', 1.6226931522950059),
#  ('voice', 1.622578202283312),
#  ('reshape', 1.6210455341856678),
#  ('limit', 1.6210420117776387),
#  ('forge', 1.6208642365330066),
#  ('reverse', 1.6165990825978378),
#  ('remind', 1.6136374718485853),
#  ('columnist', 1.613084040589364),
#  ('solicit', 1.6124019981599953),
#  ('elevate', 1.6110981765924814),
#  ('approve', 1.6099309659300551),
#  ('ought', 1.609345870187656),
#  ('orchestrate', 1.6089172185413307),
#  ('participate', 1.5998039458340827),
#  ('respect', 1.597034720803732),
#  ('undercut', 1.5944528043814696),
#  ('system', 1.594033103174444),
#  ('strip', 1.5891867184686745),
#  ('represent', 1.5853534848737985),
#  ('express', 1.579079574031398),
#  ('indicate', 1.5784033334828733),
#  ('air', 1.5777682171102776),
#  ('condemn', 1.5770259256032508),
#  ('appear', 1.5746449789679373),
#  ('unlikely', 1.5738952142347842),
#  ('likely', 1.5736001717748598),
#  ('decide', 1.5728294358343238),
#  ('withhold', 1.5698730191217942),
#  ('consolidate', 1.5684028667383476),
#  ('survey', 1.561323473738601),
#  ('effort', 1.560071878704147),
#  ('ignore', 1.5580759149740775),
#  ('comprise', 1.5524774577854434),
#  ('winner', 1.5517599090580059),
#  ('weaken', 1.550690060689705),
#  ('coordinate', 1.5489506905657544),
#  ('chairman', 1.5421512350888045),
#  ('highlight', 1.5326749522424437),
#  ('hinder', 1.5305036399742533),
#  ('eligible', 1.5291360518886408),
#  ('resent', 1.5229191325910214),
#  ('pin', 1.520870709602636),
#  ('persuade', 1.5198588047992396),
#  ('fare', 1.519225096717756),
#  ('fear', 1.5176338093372743),
#  ('bolster', 1.5175665038781079),
#  ('schedule', 1.5116416299409832),
#  ('invoke', 1.5098744256822776),
#  ('follows', 1.5097261387704373),
#  ('lament', 1.509074897967156),
#  ('seize', 1.508214991103508),
#  ('race', 1.5066618763647168),
#  ('certain', 1.5042095099960426),
#  ('enlist', 1.5041004027171148),
#  ('chance', 1.5040666869121553),
#  ('balance', 1.5009126940683997),
#  ('raise', 1.49960422926522),
#  ('lose', 1.4941926352640826),
#  ('broaden', 1.492877819724352),
#  ('interpret', 1.4918811132777192),
#  ('fail', 1.4913307493858041),
#  ('loom', 1.4903027090701315),
#  ('dispute', 1.4881906370294005),
#  ('insist', 1.4881502776679765),
#  ('thwart', 1.4871654589896341),
#  ('secure', 1.4836768650032268),
#  ('benefit', 1.4827961518049861),
#  ('embrace', 1.4757670376859444),
#  ('aid', 1.473547881889501),
#  ('claim', 1.4728487891739628),
#  ('tap', 1.4712324414131301),
#  ('perceive', 1.4700740195508282),
#  ('circulate', 1.4692537424117478),
#  ('blame', 1.4672952876543928),
#  ('lobby', 1.4665001440994556),
#  ('question', 1.463993809670163),
#  ('defend', 1.463798988931878),
#  ('compel', 1.4637768899816432),
#  ('address', 1.463068839447843),
#  ('son', 1.462685837745455),
#  ('eye', 1.4605680938775887),
#  ('concentrate', 1.4601679896741053),
#  ('diminish', 1.457893252530365),
#  ('reassure', 1.4578752591425856),
#  ('begins', 1.4576626209390087),
#  ('echo', 1.4574438840511128),
#  ('craft', 1.4571010367483483),
#  ('restrict', 1.4520115856129383),
#  ('withstand', 1.4503344016898878),
#  ('focus', 1.448467040000688),
#  ('shift', 1.447428636802376),
#  ('early', 1.4471870178932673),
#  ('complain', 1.4469245017669343),
#  ('mention', 1.4468876732219034),
#  ('finance', 1.4459349333741789),
#  ('mandate', 1.445022750650181),
#  ('define', 1.4399264849261546),
#  ('retain', 1.4367953599703314),
#  ('mark', 1.4345200209256983),
#  ('cite', 1.4330523900682806),
#  ('assure', 1.431252450419706),
#  ('spar', 1.4299355741654383),
#  ('pick', 1.4275283169280832),
#  ('preach', 1.425446846909354),
#  ('label', 1.42485858272939),
#  ('endanger', 1.4247698685274381),
#  ('hint', 1.4230917757712498),
#  ('restore', 1.422388505855193),
#  ('spend', 1.4222422405019761),
#  ('contend', 1.4212426701922476),
#  ('believe', 1.4197137736447507),
#  ('underestimate', 1.4192490111833964),
#  ('skeptical', 1.4183242534085607),
#  ('overcome', 1.4182668003374976),
#  ('wave', 1.4176466199936675),
#  ('sum', 1.4164929709928107),
#  ('upset', 1.4140401640530378),
#  ('prohibit', 1.412792097489543),
#  ('jeopardize', 1.411245521201443),
#  ('mistake', 1.4111838152692948),
#  ('guarantee', 1.409489679871136),
#  ('conduct', 1.4066749494700312),
#  ('member', 1.404014853743001),
#  ('liken', 1.4031826439360366),
#  ('signal', 1.4030355123535658),
#  ('proclaim', 1.4029570226228794),
#  ('brush', 1.4027356718558666),
#  ('ponder', 1.40139129120734),
#  ('revive', 1.4008436998320317),
#  ('relish', 1.4000873638916846),
#  ('strengthen', 1.3997967519230448),
#  ('sponsor', 1.3987633333394223),
#  ('active', 1.3981232802191104),
#  ('affirm', 1.3979645253210071),
#  ('authorize', 1.3965437741323916),
#  ('deepen', 1.3957305186238582),
#  ('head', 1.391561068425008),
#  ('repeat', 1.3867931810261462),
#  ('acknowledge', 1.3846667565917565),
#  ('accurate', 1.3806644708196678),
#  ('punish', 1.3793680116054956),
#  ('important', 1.379302785758258),
#  ('waste', 1.3769061409545873),
#  ('favorite', 1.369951202228139),
#  ('intervene', 1.368410127522094),
#  ('accept', 1.3673165696452931),
#  ('unclear', 1.3654255838694354),
#  ('worried', 1.3635682493091061),
#  ('prefer', 1.3619402260132396),
#  ('narrow', 1.3593618496919975),
#  ('volunteer', 1.3580140034340236),
#  ('skip', 1.356685646155144),
#  ('refuse', 1.3560806550708457),
#  ('serve', 1.353249004994431),
#  ('shun', 1.3529540364946995),
#  ('crush', 1.351825756397268),
#  ('contribute', 1.351320331649601),
#  ('convinced', 1.3510448805678297),
#  ('speak', 1.3503621635971879),
#  ('bless', 1.347286462623777),
#  ('matter', 1.347261789484511),
#  ('result', 1.3471145896080965),
#  ('betray', 1.3469426352715081),
#  ('lead', 1.3465789359318348),
#  ('doubt', 1.3445973692239768),
#  ('intensify', 1.3440320175787004),
#  ('shock', 1.343719707155038),
#  ('press', 1.3431288852027827),
#  ('interfere', 1.342796233082609),
#  ('characterize', 1.3426206702201362),
#  ('spell', 1.3423931268652274),
#  ('impossible', 1.342154838310649),
#  ('regard', 1.3420857344843873),
#  ('wrong', 1.3402278065066855),
#  ('reinforce', 1.3385938693382864),
#  ('deny', 1.3333111663425443),
#  ('shout', 1.332740924581808),
#  ('dog', 1.3267674552527398),
#  ('devote', 1.3266839763934737),
#  ('cheer', 1.3258620055287056),
#  ('battle', 1.3208707586966582),
#  ('fight', 1.3186674372662779),
#  ('permit', 1.3159629219526299),
#  ('propose', 1.3132829661406404),
#  ('significant', 1.3126471992695716),
#  ('concerned', 1.3125845740216802),
#  ('consider', 1.3125705605223557),
#  ('hop', 1.3122666970851742),
#  ('resolve', 1.3121872187557522),
#  ('stag', 1.307797508525726),
#  ('divert', 1.3066617108314682),
#  ('reflect', 1.3029831332095299),
#  ('attract', 1.302742099993362),
#  ('illegal', 1.3014930376405824),
#  ('ensure', 1.2998000655052655),
#  ('key', 1.2920548085047718),
#  ('hope', 1.2901505806290205),
#  ('form', 1.2886588909753216),
#  ('stir', 1.2879917879788676),
#  ('manipulate', 1.286780475314143),
#  ('distinguish', 1.2819119703446993),
#  ('apologize', 1.2811909176614655),
#  ('designate', 1.2805250716331815),
#  ('deliver', 1.2799725078158763),
#  ('promote', 1.278473010409091),
#  ('dwindle', 1.278176889985131),
#  ('successful', 1.2777865688636187),
#  ('change', 1.2777253386155516),
#  ('proud', 1.2755046515523938),
#  ('thank', 1.2738042419827),
#  ('mirror', 1.2736163186174545),
#  ('credit', 1.2728675916156693),
#  ('prove', 1.2700076012825556),
#  ('provoke', 1.2682606473212679),
#  ('suggest', 1.266516989428712),
#  ('reply', 1.2658333321192994),
#  ('reap', 1.263155942686515),
#  ('clinch', 1.2630118973907354),
#  ('stand', 1.2618644101242416),
#  ('protest', 1.2614778528794277),
#  ('erupt', 1.261351434196963),
#  ('issue', 1.259535969876015),
#  ('command', 1.2583119933466083),
#  ('risk', 1.25774679776577),
#  ('tend', 1.2573416573478935),
#  ('undertake', 1.2514144143575376),
#  ('over', 1.249956187011912),
#  ('note', 1.2474158298479014),
#  ('fulfill', 1.2459469985781781),
#  ('march', 1.24544108732227),
#  ('clear', 1.243218683227088),
#  ('care', 1.243029432669428),
#  ('deem', 1.2417011508748401),
#  ('violate', 1.240554703371217),
#  ('force', 1.2392511719915436),
#  ('plot', 1.2384020260224216),
#  ('people', 1.2369833511063928),
#  ('evident', 1.2357379565520656),
#  ('distribute', 1.2336667381347526),
#  ('moment', 1.2327487706389129),
#  ('admire', 1.2318641595106585),
#  ('applaud', 1.2287644958544715),
#  ('engage', 1.228492071790411),
#  ('worry', 1.2273211655167264),
#  ('inherit', 1.2268346901709923),
#  ('constitute', 1.22438246606978),
#  ('gather', 1.2222928603530534),
#  ('monitor', 1.2221832551261218),
#  ('pave', 1.2199362493810564),
#  ('man', 1.21892966498989),
#  ('object', 1.2188921494661948),
#  ('launch', 1.2181989328151108),
#  ('quote', 1.2178298435845514),
#  ('pump', 1.2157659438831256),
#  ('carry', 1.2149108796396437),
#  ('threaten', 1.2139250274653035),
#  ('depend', 1.211940195289925),
#  ('steer', 1.2116524616659123),
#  ('percent', 1.2115072245400191),
#  ('tolerate', 1.2107909336700806),
#  ('help', 1.2087026520794333),
#  ('decision', 1.2073998241796888),
#  ('forbid', 1.20456048982136),
#  ('impose', 1.203930101519374),
#  ('person', 1.2034542065543095),
#  ('enforce', 1.2010574970375343),
#  ('adopt', 1.1995054843337718),
#  ('optimistic', 1.1994710881241692),
#  ('pass', 1.1974539133068638),
#  ('retire', 1.1960301857734261),
#  ('deploy', 1.191666744935385),
#  ('surface', 1.1877174807795312),
#  ('pour', 1.1857759021991296),
#  ('lack', 1.184087476802668),
#  ('eager', 1.184086781580688),
#  ('broadcast', 1.1806342404218628),
#  ('takes', 1.1799093895506765),
#  ('rattle', 1.17904660139608),
#  ('base', 1.178209700193046),
#  ('announce', 1.1750545336908575),
#  ('term', 1.1748544664374814),
#  ('shy', 1.1739993171710863),
#  ('quit', 1.173890434980502),
#  ('submit', 1.173494227106006),
#  ('illustrate', 1.1723414028204568),
#  ('joke', 1.1701874490735056),
#  ('opt', 1.1692834216387153),
#  ('step', 1.1669067226598708),
#  ('solve', 1.164284459649353),
#  ('in', 1.162731222522043),
#  ('will', 1.1578358296179534),
#  ('replace', 1.1569322441013041),
#  ('enough', 1.1559368282812887),
#  ('dare', 1.1555500762245214),
#  ('shake', 1.1540148407083193),
#  ('hurt', 1.1539327163729434),
#  ('require', 1.153865566565686),
#  ('resist', 1.153082474133253),
#  ('respond', 1.1526585872504531),
#  ('gain', 1.1499232033250557),
#  ('end', 1.14811930943575),
#  ('amount', 1.14636501383149),
#  ('harm', 1.1447306185683461),
#  ('imply', 1.1408588816556973),
#  ('flood', 1.1402749651681947),
#  ('compromise', 1.1390610393293725),
#  ('outline', 1.138375764152154),
#  ('warn', 1.1357464417195418),
#  ('worsen', 1.1346798966443075),
#  ('seem', 1.1337573552006348),
#  ('identify', 1.1324065429691281),
#  ('careful', 1.132216141759734),
#  ('exercise', 1.131634340756525),
#  ('affect', 1.1285645873784278),
#  ('quick', 1.1277960462611074),
#  ('scar', 1.1262861327445175),
#  ('cancel', 1.1245253610381918),
#  ('dub', 1.1208759672626845),
#  ('true', 1.1197392442283347),
#  ('summon', 1.1161922234572732),
#  ('advertise', 1.1141730957590348),
#  ('beat', 1.113892488665179),
#  ('describe', 1.112439279276471),
#  ('deserve', 1.1124184501189431),
#  ('interrupt', 1.1103632791978992),
#  ('remain', 1.1103317461874982),
#  ('erode', 1.1100857912925703),
#  ('essential', 1.109960617948348),
#  ('interview', 1.1077882937032006),
#  ('precede', 1.1057224741929124),
#  ('attempt', 1.1044209258902342),
#  ('translate', 1.104158546746047),
#  ('rival', 1.1040295660433588),
#  ('disappointed', 1.1038300757880897),
#  ('bill', 1.1033221967027662),
#  ('widen', 1.1013054357591499),
#  ('encourage', 1.095898635793746),
#  ('call', 1.0955950366758727),
#  ('demand', 1.0955827916821035),
#  ('correct', 1.0937457356803515),
#  ('halt', 1.0936262488137787),
#  ('sense', 1.0929592751112858),
#  ('join', 1.0913442063258736),
#  ('reluctant', 1.0888138702047674),
#  ('dictate', 1.0867462004989819),
#  ('exploit', 1.0860668300500909),
#  ('point', 1.0840196666205582),
#  ('welcome', 1.0830837559517752),
#  ('contemplate', 1.0813532622346402),
#  ('avoid', 1.080717143901098),
#  ('implement', 1.080481617819705),
#  ('unable', 1.0796126486427358),
#  ('soften', 1.0784262154431872),
#  ('strong', 1.0779044670089755),
#  ('greet', 1.0732024087050562),
#  ('give', 1.0723151483955666),
#  ('inject', 1.0704446576729816),
#  ('prompt', 1.0694338072393612),
#  ('agree', 1.0692925027009312),
#  ('tighten', 1.068636239147998),
#  ('list', 1.067644237001425),
#  ('friend', 1.067643956119953),
#  ('encompass', 1.0642497063951106),
#  ('unfold', 1.0639554560291336),
#  ('scan', 1.0638845788955722),
#  ('block', 1.0637936483389787),
#  ('observe', 1.0620954781519538),
#  ('oversee', 1.060672366846227),
#  ('push', 1.0599191218681998),
#  ('concern', 1.0597723565814672),
#  ('director', 1.058516137055179),
#  ('reiterate', 1.0574433894387048),
#  ('attribute', 1.0549565529367164),
#  ('advise', 1.05275825567489),
#  ('serious', 1.052485590362816),
#  ('surprising', 1.0520172317805507),
#  ('scramble', 1.0500070653765872),
#  ('persist', 1.0472560692614696),
#  ('proceed', 1.0467042893428478),
#  ('say', 1.0453302536608389),
#  ('c.', 1.04514566620202),
#  ('confront', 1.0434350278824471),
#  ('would', 1.0427204747977488),
#  ('near', 1.0426014282414515),
#  ('turn', 1.0387229947069663),
#  ('recognize', 1.037402332441064),
#  ('become', 1.0367086039982054),
#  ('boast', 1.0364317897434219),
#  ('preserve', 1.034278652729052),
#  ('invite', 1.0338459088343526),
#  ('surprise', 1.0334231516874857),
#  ('react', 1.0330365096376932),
#  ('number', 1.032953244042653),
#  ('present', 1.0325766815700739),
#  ('maintain', 1.0313122119056553),
#  ('talk', 1.0297937215898803),
#  ('try', 1.029487366257575),
#  ('attend', 1.0285395304673401),
#  ('effective', 1.0283291065188223),
#  ('instruct', 1.0268550752047507),
#  ('equal', 1.0252887260893455),
#  ('willing', 1.0241923163543583),
#  ('exclude', 1.023820876949168),
#  ('_', 1.0237903723917245),
#  ('weak', 1.0219384053478306),
#  ('prevent', 1.020510021758435),
#  ('time', 1.019816580369633),
#  ('free', 1.0198160531805234),
#  ('alter', 1.0178651230398108),
#  ('author', 1.0146063651687778),
#  ('wound', 1.0145163075897654),
#  ('assume', 1.0138769509201828),
#  ('stall', 1.013830934568997),
#  ('think', 1.0135358446260614),
#  ('mean', 1.012377914135282),
#  ('fund', 1.0112732807888303),
#  ('delay', 1.0112305837364617),
#  ('caution', 1.0111758191967337),
#  ('allow', 1.0094305499255998),
#  ('establish', 1.0078807202546582),
#  ('assemble', 1.0076876740055525),
#  ('renew', 1.0049313537856972),
#  ('forgive', 1.004596678173498),
#  ('afraid', 1.003546837285604),
#  ('send', 1.002461159646219),
#  ('protect', 1.0011845491872775),
#  ('put', 1.000338402273033)]

# %% [markdown]
# ---
