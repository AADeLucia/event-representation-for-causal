# %% [markdown]
# * https://www.nltk.org/howto/wordnet.html

# %%
import nltk
import jsonlines
import collections
import os
import json
from nltk.corpus import wordnet as wn
from collections import Counter

lemmatizer = nltk.stem.WordNetLemmatizer()

# %%
synsets = {
    "protests": {
        "police": wn.synset('law_enforcement_agency.n.01').name(),
        "bush": wn.synset('politician.n.02').name(),
        "putin": wn.synset('politician.n.02').name(),
        "hussein": wn.synset('politician.n.02').name(),
        "hizballah": wn.synset('politician.n.02').name(),
        "hezbollah": wn.synset('politician.n.02').name(),
        "gore": wn.synset('politician.n.02').name(),
        "politician": wn.synset('politician.n.02').name(),
        "gore": wn.synset('politician.n.02').name(),
        
        "city": wn.synset('urban_area.n.01').name(),
        "broadway": wn.synset('urban_area.n.01').name(),
        "orleans": wn.synset('urban_area.n.01').name(),
        "tokyo": wn.synset('urban_area.n.01').name(),
        "selma": wn.synset('urban_area.n.01').name(),
        "guadalajara": wn.synset('urban_area.n.01').name(),
        "paris": wn.synset('urban_area.n.01').name(),
        "zaragoza": wn.synset('urban_area.n.01').name(),
        "beijing": wn.synset('urban_area.n.01').name(),
        "washington": wn.synset('urban_area.n.01').name(),
        "zaragoza": wn.synset('urban_area.n.01').name(),
        
        "demonstrator": wn.synset('reformer.n.01').name(),
        "protester": wn.synset('reformer.n.01').name(),
        "demonstration": wn.synset('protest.n.02').name(),
        "protest": wn.synset('protest.n.02').name(),
        "sit-in": wn.synset('protest.n.02').name(),
        "march": wn.synset('protest.n.02').name(),
        "rally": wn.synset('protest.n.02').name(),
        
        "woman": wn.synset('person.n.01').name(),
        "man": wn.synset('person.n.01').name(),
        "daughter": wn.synset('person.n.01').name(),
        "student": wn.synset('person.n.01').name(),
        "group": wn.synset('group.n.01').name(),

        
        "japan": wn.synset('political_unit.n.01').name(),
        "china": wn.synset('political_unit.n.01').name(),
        "israel": wn.synset('political_unit.n.01').name(),
        "isreal": wn.synset('political_unit.n.01').name(),
        "egypt": wn.synset('political_unit.n.01').name(),
        "lithuania": wn.synset('political_unit.n.01').name(),
        "lebanon": wn.synset('political_unit.n.01').name(),
        "haiti": wn.synset('political_unit.n.01').name(),
        "fiji": wn.synset('political_unit.n.01').name(),
        "nigeria": wn.synset('political_unit.n.01').name(),
        "cuba": wn.synset('political_unit.n.01').name(),
        "iraq": wn.synset('political_unit.n.01').name(),
        "uganda": wn.synset('political_unit.n.01').name(),
        "cuba": wn.synset('political_unit.n.01').name(),
        "cuba": wn.synset('political_unit.n.01').name(),
        "cuba": wn.synset('political_unit.n.01').name(),
        "cuba": wn.synset('political_unit.n.01').name(),
    },
    "disease_outbreak": {
        "organism": wn.synset('organism.n.01').name(),
        "fly": wn.synset('organism.n.01').name(),
        "cat": wn.synset('organism.n.01').name(),
        "rat": wn.synset('organism.n.01').name(),
        "mosquito": wn.synset('organism.n.01').name(),
        "cattle": wn.synset('organism.n.01').name(),
        "bird": wn.synset('organism.n.01').name(),
        "mouse": wn.synset('organism.n.01').name(),
        "gorilla": wn.synset('organism.n.01').name(),
        "deer": wn.synset('organism.n.01').name(),
        "horse": wn.synset('organism.n.01').name(),
        "worm": wn.synset('organism.n.01').name(),
        "bat": wn.synset('organism.n.01').name(),
        "sheep": wn.synset('organism.n.01').name(),
        "cow": wn.synset('organism.n.01').name(),
        "dog": wn.synset('organism.n.01').name(),
        "livestock": wn.synset('organism.n.01').name(),
        "bison": wn.synset('organism.n.01').name(),
        "duck": wn.synset('organism.n.01').name(),
        "frog": wn.synset('organism.n.01').name(),
        "chimpanzee": wn.synset('organism.n.01').name(),
        "pigeon": wn.synset('organism.n.01').name(),
        "swan": wn.synset('organism.n.01').name(),
        "shellfish": wn.synset('organism.n.01').name(),
        "pig": wn.synset('organism.n.01').name(),
        "salmon": wn.synset('organism.n.01').name(),
        "trout": wn.synset('organism.n.01').name(),
        "tick": wn.synset('organism.n.01').name(),
        "fish": wn.synset('organism.n.01').name(),
        "ferret": wn.synset('organism.n.01').name(),
        "rodent": wn.synset('organism.n.01').name(),
        "gerbil": wn.synset('organism.n.01').name(),
        "hamster": wn.synset('organism.n.01').name(),
        "raccoon": wn.synset('organism.n.01').name(),
        "lion": wn.synset('organism.n.01').name(),
        "crab": wn.synset('organism.n.01').name(),
        "elk": wn.synset('organism.n.01').name(),
        "mammal": wn.synset('organism.n.01').name(),
        "toad": wn.synset('organism.n.01').name(),
        "salmon": wn.synset('organism.n.01').name(),
        
        "poultry": wn.synset('food.n.02').name(),
        "beef": wn.synset('food.n.02').name(),
                
        "mumps": wn.synset('illness.n.01').name(),
        "meningitis": wn.synset('illness.n.01').name(),
        "polio": wn.synset('illness.n.01').name(),
        "tuberculosis": wn.synset('illness.n.01').name(),
        "dysentery": wn.synset('illness.n.01').name(),
        "leprosy": wn.synset('illness.n.01').name(),
        "cholera": wn.synset('illness.n.01').name(),
        "herpes": wn.synset('illness.n.01').name(),
        "fibrosis": wn.synset('illness.n.01').name(),
        "osteoporosis": wn.synset('illness.n.01').name(),
        "sclerosis": wn.synset('illness.n.01').name(),
        "influenza": wn.synset('illness.n.01').name(),
        "flu": wn.synset('illness.n.01').name(),
        "sickness": wn.synset('illness.n.01').name(),
        "infection": wn.synset('illness.n.01').name(),
        "illness": wn.synset('illness.n.01').name(),
        "injury": wn.synset('illness.n.01').name(),
        "leukemia": wn.synset('illness.n.01').name(),
        "carcinoma": wn.synset('illness.n.01').name(),
        "hiv": wn.synset('illness.n.01').name(),
        "asbestosis": wn.synset('illness.n.01').name(),
        "smallpox": wn.synset('illness.n.01').name(),
        "rabies": wn.synset('illness.n.01').name(),
        "anemia": wn.synset('illness.n.01').name(),
        "encephalitis": wn.synset('illness.n.01').name(),
        "zoonosis": wn.synset('illness.n.01').name(),
        "rinderpest": wn.synset('illness.n.01').name(),
        "bse": wn.synset('illness.n.01').name(),
        "osteoarthritis": wn.synset('illness.n.01').name(),
        "sepsis": wn.synset('illness.n.01').name(),
        "cancer": wn.synset('illness.n.01').name(),
        "trachoma": wn.synset('illness.n.01').name(),
        "malaria": wn.synset('illness.n.01').name(),
        "melanoma": wn.synset('illness.n.01').name(),
        "angioma": wn.synset('illness.n.01').name(),
        "plague": wn.synset('illness.n.01').name(),
        "sars": wn.synset('illness.n.01').name(),
        "pneumonia": wn.synset('illness.n.01').name(),
        "parkinson": wn.synset('illness.n.01').name(),
        "psoriasis": wn.synset('illness.n.01').name(),
        "arthritis": wn.synset('illness.n.01').name(),
        "mucopolysaccharidosis": wn.synset('illness.n.01').name(),
        "gonorrhea": wn.synset('illness.n.01').name(),
        "plague": wn.synset('illness.n.01').name(),
        "plague": wn.synset('illness.n.01').name(),
        "plague": wn.synset('illness.n.01').name(),
        "plague": wn.synset('illness.n.01').name(),
   
        "intestine": wn.synset('body_part.n.01').name(),
        "liver": wn.synset('body_part.n.01').name(),
        "lung": wn.synset('body_part.n.01').name(),
        "heart": wn.synset('body_part.n.01').name(),
        "lung": wn.synset('body_part.n.01').name(),
        "lung": wn.synset('body_part.n.01').name(),
        "lung": wn.synset('body_part.n.01').name(),
        "lung": wn.synset('body_part.n.01').name(),

        "bacillus": wn.synset('infectious_agent.n.01').name(),
        "spirochete": wn.synset('infectious_agent.n.01').name(),
        "microbe": wn.synset('infectious_agent.n.01').name(),
        "bacteria": wn.synset('infectious_agent.n.01').name(),
        "bacterium": wn.synset('infectious_agent.n.01').name(),
        "bacillus": wn.synset('infectious_agent.n.01').name(),
                
    },
    "election": {
        "bush": wn.synset('campaigner.n.01').name(),
        "gore": wn.synset('campaigner.n.01').name(),
        "clinton": wn.synset('campaigner.n.01').name(),
        "nixon": wn.synset('campaigner.n.01').name(),
        "bush": wn.synset('campaigner.n.01').name(),
        
        "conservative": wn.synset('political_orientation.n.01').name(),
        "liberal": wn.synset('political_orientation.n.01').name(),
        "moderate": wn.synset('political_orientation.n.01').name(),
        "nationalist": wn.synset('political_orientation.n.01').name(),
        "center": wn.synset('political_orientation.n.01').name(),
        "middle": wn.synset('political_orientation.n.01').name(),
        "left": wn.synset('political_orientation.n.01').name(),
        "right": wn.synset('political_orientation.n.01').name(),
        "center": wn.synset('political_orientation.n.01').name(),

    },
    "arrest": {},
    "plane_crash": {
        "plane": wn.synset('airplane.n.01').name(),
        "helicopter": wn.synset('airplane.n.01').name(),
        "sailplane": wn.synset('airplane.n.01').name(),
        "airplane": wn.synset('airplane.n.01').name(),
        "glider": wn.synset('airplane.n.01').name(),
        "warplane": wn.synset('airplane.n.01').name(),
        "jetliner": wn.synset('airplane.n.01').name(),
        "aircraft": wn.synset('airplane.n.01').name(),
        "turboprop": wn.synset('airplane.n.01').name(),
        "warplane": wn.synset('airplane.n.01').name(),
        "warplane": wn.synset('airplane.n.01').name(),
        "warplane": wn.synset('airplane.n.01').name(),
    }
}

stopwords = {"we", "they", "who", "which", "that", "i", "it", "he", "she", "them", "him", "her", "u", "me", "a"}

# %%
schema = "disease_outbreak"

# Load key verbs
with open("/srv/local2/adeluci2/event-representation-for-causal/results/schema_verbs.json") as f:
    key_verbs = set(json.load(f)[schema])

common_preds_args = Counter()
common_args = Counter()
generalized_terms = {}
related_docs = f"/srv/local2/adeluci2/event-representation-for-causal/results/{schema}/nyt_en_{schema}.jsonl.predargs"


with jsonlines.open(related_docs) as reader:
    for obj in reader.iter():
        for pred_args in obj['pred_args']:
            all_lines += 1
            pred_idx = pred_args[2]
            arg_idx = 1 - pred_idx
            pred, arg = pred_args[pred_idx], pred_args[arg_idx].lower()
            arg = lemmatizer.lemmatize(arg, pos=wn.NOUN)
            if pred not in key_verbs or arg.lower() in stopwords:
                continue
            
            # Check if word is in the custom synset list
            # Use WordNet lookup if not
            if arg in synsets[schema]:
                syn_root = synsets[schema][arg]
            else:
                if not wn.synsets(arg, pos=wn.NOUN):
                    not_matched += 1
                    continue
                syn = wn.synsets(arg, pos=wn.NOUN)[0]
                if syn.hypernyms():
                    syn_root = syn.hypernyms()[0].name()
                else:
                    syn_root = syn.name()
            common_preds_args.update([(pred, syn_root, pred_idx)])
            common_args.update([arg])
            generalized_terms[syn_root] = generalized_terms.get(syn_root, set())
            generalized_terms[syn_root].add(arg)
            
            # print(f"Pred: {pred}\tArg: {arg}\t{syn_root}")

# %%
# Greedy algorithm to match args with most frequent synsets across all args

def score_synset(synset_name, cur_cnt):
    # Only consider counts below `cur_cnt`, to align with the greedy nature of the approach
    return sum(cnt for _, cnt in inv_synset_index[synset_name] if cnt <= cur_cnt)

# First pass: build inverted index
inv_synset_index = collections.defaultdict(set)
for arg, cnt in common_args.most_common():
    if cnt >= 5:
        synsets = wn.synsets(arg, pos=wn.NOUN)
        for synset in synsets:
            parent_synsets = [y.name() for y in synset.hypernyms()]
            inv_synset_index[synset.name()].add((arg, cnt))
            for parent_synset in parent_synsets:
                inv_synset_index[parent_synset].add((arg, cnt))
        
# Second pass: assign args to synsets in a greedy manner
arg_to_synset = {}
for arg, cur_cnt in common_args.most_common(): 
    if arg not in arg_to_synset:
        synsets = wn.synsets(arg, pos=wn.NOUN)
        cand_synsets = []
        for synset in synsets:
            cand_synsets.append((score_synset(synset.name(), cur_cnt), 1, synset.name()))
            for parent_synset in synset.hypernyms():
                cand_synsets.append((score_synset(parent_synset.name(), cur_cnt), 0, parent_synset.name()))
        cand_synsets = list(set(cand_synsets))
        _, _, best_synset_name = max(cand_synsets)
        # Assign less-or-equal frequent args' synset to `best_synset_name`
        for lf_arg, cnt in inv_synset_index[best_synset_name]:
            if cnt <= cur_cnt:
                arg_to_synset[lf_arg] = best_synset_name
    # print(f'{arg} (cnt = {cur_cnt}) -> {arg_to_synset[arg]}')

# %%
common_preds_args.most_common(10)
# Out:
# [(('spread', 'illness.n.01', 0), 649),
#  (('treat', 'illness.n.01', 0), 188),
#  (('spread', 'illness.n.01', 1), 175),
#  (('spread', 'infectious_agent.n.01', 0), 97),
#  (('transmit', 'illness.n.01', 0), 85),
#  (('infect', 'group.n.01', 0), 67),
#  (('spread', 'organism.n.01', 1), 61),
#  (('transmit', 'infectious_agent.n.01', 0), 54),
#  (('infect', 'organism.n.01', 0), 50),
#  (('treat', 'case.n.06', 0), 47)]

# %%
{arg: (cnt, arg_to_synset[arg]) for arg, cnt in common_args.most_common(10)}
# Out:
# {'disease': (908, 'illness.n.01'),
#  'virus': (174, 'microorganism.n.01'),
#  'people': (157, 'group.n.01'),
#  'infection': (67, 'communication.n.02'),
#  'patient': (63, 'case.n.06'),
#  'word': (47, 'word.n.01'),
#  'cancer': (46, 'person.n.01'),
#  'bacteria': (44, 'microorganism.n.01'),
#  'file': (44, 'file.n.04'),
#  'human': (41, 'homo.n.02')}

# %%
for arg, count in common_args.most_common():
    if arg[1] != "illness.n.01":
        continue
    print(f"{arg}\t{count:,}")
# Out:
# ('spread', 'illness.n.01')	824
# ('treat', 'illness.n.01')	188
# ('transmit', 'illness.n.01')	85
# ('infect', 'illness.n.01')	44
# ('study', 'illness.n.01')	35
# ('diagnose', 'illness.n.01')	35
# ('cure', 'illness.n.01')	27
# ('evolve', 'illness.n.01')	9
# ('test', 'illness.n.01')	4

# %%
for root, args in generalized_terms.items():
    print(f"{root}\t{' '.join(args)}")
# Out:
# illness.n.01	bse mucopolysaccharidosis osteoarthritis parkinson zoonosis encephalitis gonorrhea sickness influenza dysentery osteoporosis carcinoma anemia sepsis meningitis disease amyloidosis injury herpes flu mumps tuberculosis infection angioma plague leprosy melanoma hiv cancer cholera sars asbestosis trachoma pneumonia sclerosis smallpox fibrosis polio rinderpest illness psoriasis leukemia rabies arthritis malaria
# group.n.01	people
# body_part.n.01	lung intestine tissue liver heart organ
# abstraction.n.06	group
# example.n.01	specimen sample
# infectious_agent.n.01	bacteria pathogen virus bacterium spirochete microbe bacillus
# large_integer.n.01	100 21 thousand hundred million 12 twelve 14
# more.n.01	more
# state.n.02	situation being condition
# plan_of_action.n.01	strategy
# case.n.06	patient
# organism.n.01	frog pig salmon animal dog duck mouse ferret parasite pigeon lion gerbil shellfish crab cat bat organism elk horse gorilla mutation rat toad bird hamster mosquito fish fungus trout raccoon cattle mammal swan worm bison cow tick livestock deer sheep chimpanzee rodent fly
# hominid.n.01	human
# causal_agent.n.01	individual someone person agent
# record.n.01	file
# compartment.n.01	cell
# digit.n.01	one
# kind.n.01	type
# enrollee.n.01	student
# medical_building.n.01	hospital
# doctor.n.01	veterinarian
# control.n.01	authority
# outbreak.n.01	epidemic
# inquirer.n.01	pollster
# heavier-than-air_craft.n.01	airplane
# associate.n.01	participant co-worker member
# activity.n.01	work protection practice market procedure use effort attempt
# currency.n.01	specie cash
# word.n.01	form
# happening.n.01	case flare-up change outbreak flash
# unfortunate.n.01	sufferer victim prisoner
# resource.n.02	aid
# arthropod.n.01	insect
# breathing.n.01	smoking
# immunogen.n.01	vaccine
# conceptualization.n.01	approach
# computer_network.n.01	net
# property.n.04	characteristic feature
# biology.n.01	genetics
# representation.n.02	photo
# increase.n.02	jump
# spouse.n.01	husband wife
# time_period.n.01	year stage phase season
# financial_condition.n.01	wealth
# fullness.n.03	infestation
# abstinence.n.02	fast
# proportion.n.01	percent
# communication.n.02	signal message
# implement.n.01	stick
# trainer.n.01	handler
# scientist.n.01	biologist investigator researcher paleontologist
# fear.n.01	terror consternation alarm panic
# zoonosis.n.01	anthrax
# staphylococcal_infection.n.01	boil
# fugitive.n.02	escapee
# poison.n.01	toxin
# radical.n.03	terrorist
# content.n.05	thought issue idea belief
# hypothesis.n.02	model
# division.n.04	department
# place.n.02	hatchery
# animal_group.n.01	breed herd
# polity.n.02	government
# agency.n.01	cdc fda
# symptom.n.01	diarrhea inflammation pain spasm fever cough
# deformation.n.02	strain
# person.n.01	killer anti user adult winker relative explorer worker traveler expert scientist
# interest.n.01	concern
# plant_disease.n.01	canker
# skilled_worker.n.01	technician official
# psychosis.n.01	paranoia
# custom.n.01	ritual
# collection.n.01	variety category set law combination
# precipitation.n.03	rain
# particle.n.02	prion
# scientific_research.n.01	experiment
# change_of_integrity.n.01	burning
# situation.n.01	environment thing
# critic.n.02	grader
# inspiration.n.01	germ
# language_unit.n.01	word
# priesthood.n.01	ministry
# knowing.n.01	awareness
# body_of_water.n.01	waterway
# region.n.03	area district
# government_officials.n.01	bureaucracy
# west_indian.n.01	haitian
# physical_condition.n.01	disorder addiction
# eubacteria.n.01	b
# message.n.02	story publicity information subject request
# vascular_plant.n.01	vine weed
# chemical.n.01	herbicide fertilizer
# output.n.02	crop
# political_unit.n.01	country
# metallic_element.n.01	cf tb
# municipality.n.01	city
# set.n.01	pair
# application.n.01	technology
# edge_tool.n.01	knife
# breath.n.01	inhalation
# wound.n.01	bite
# property.n.02	age way level
# condition.n.01	malady safety
# restaurant.n.01	lunchroom
# common_fraction.n.01	third half
# plant_fiber.n.01	straw
# care.n.01	treatment
# secretion.n.02	mucus
# explanation.n.02	theory
# proposal.n.01	hypothesis
# relation.n.01	connection part
# amount.n.02	number
# male_offspring.n.01	son
# medical_practitioner.n.01	physician doctor
# discipline.n.01	science
# bantu.n.02	chaga
# liquid_body_substance.n.01	blood
# emotion.n.01	fear
# body_waste.n.01	feces urine
# discontentment.n.01	dissatisfaction
# wellbeing.n.01	health
# meaning.n.01	nuance
# vital_principle.n.01	spirit
# injury.n.02	concussion
# sending.n.01	transmission
# change_of_location.n.01	spread
# resident.n.01	inmate
# enthusiast.n.01	addict
# domestic_partner.n.01	partner spouse
# adult.n.01	man woman host
# gossip.n.02	rumor
# diversion.n.01	sport
# inhabitant.n.01	resident american
# psychological_state.n.01	depression anxiety irritation
# medical_care.n.01	therapy
# skill.n.01	literacy
# juvenile.n.01	child adolescent kid
# body_covering.n.01	skin
# container.n.01	can dispenser
# room.n.01	john
# attitude.n.01	tendency
# geographical_area.n.01	tract
# hour.n.02	none
# physical_phenomenon.n.01	cloud
# medicine.n.02	physic dose
# infection.n.01	sore
# instrument.n.01	weapon
# interaction.n.01	contact
# organ.n.01	wing
# phenomenon.n.01	result effect
# force.n.04	men military
# polarity.n.02	negativity
# plant_material.n.01	wood
# difficulty.n.03	problem
# experiment.n.02	test
# direction.n.01	trend
# limb.n.01	arm
# laborer.n.01	sprayer
# diagnostic_procedure.n.01	mammography
# quality.n.01	nature ability
# agamete.n.01	spore
# commitment.n.04	promise
# gathering.n.01	grade
# material.n.01	particle waste
# electrical_phenomenon.n.01	current
# evidence.n.01	symptom proof
# revolutionary_group.n.01	underground
# idea.n.01	plan program
# building_complex.n.01	plant
# ectoparasite.n.01	flea
# farmhand.n.01	milkmaid
# flower.n.01	petunia portulaca
# injury.n.01	bump fracture bleeding
# organization.n.01	personnel
# administrative_district.n.01	state
# degree.n.06	c
# new_jersey.n.01	jersey
# nonaccomplishment.n.01	failure
# attempt.n.01	best trial
# dynasty.n.01	york
# pedestrian.n.01	hiker
# case.n.01	time
# expectation.n.01	possibility
# insect.n.01	bug
# system.n.02	network
# intruder.n.01	stranger
# people.n.01	population blind sick
# cereal.n.01	corn wheat
# effort.n.02	exercise
# wood.n.01	oak
# mainframe.n.01	supercomputer
# drive.n.05	initiative
# linear_unit.n.01	inch yard mile
# traveler.n.01	passenger visitor
# antiviral.n.01	ribavirin
# extent.n.02	range
# request.n.01	demand
# unit.n.03	team
# interrogation.n.03	interview
# medical_science.n.01	surgery medicine
# epidemic.n.01	pandemic
# maine.n.01	maine
# elite.n.01	few
# passion.n.01	fervor
# male_sibling.n.01	brother
# relative.n.01	sibling
# substance.n.01	fluid material
# eruption.n.02	rash
# polygenic_disorder.n.01	diabetes
# external_body_part.n.01	head
# medical_institution.n.01	clinic
# examination.n.01	study survey scan
# malone.n.01	malone
# antibacterial.n.01	antibiotic
# artifact.n.01	facility cloth layer
# simple_leaf.n.01	needle
# residence.n.01	home
# guard.n.01	screener
# haiti.n.01	haiti
# spiritual_leader.n.01	rabbi
# workplace.n.01	laboratory
# edible_fruit.n.01	berry citrus
# georgia.n.01	georgia
# anticipation.n.01	hope
# loner.n.01	recluse
# army_unit.n.01	division
# large_indefinite_quantity.n.01	lot
# victim.n.01	casualty
# binary_compound.n.01	water
# raincoat.n.01	mac
# child.n.02	infant baby
# thomas.n.01	thomas
# businessperson.n.01	businessman
# part.n.02	segment piece
# falsehood.n.01	lie
# relative_quantity.n.01	enough
# communication.n.01	exam
# consequence.n.01	byproduct
# natural_object.n.01	rock body
# kinswoman.n.01	aunt
# division.n.03	fragmentation
# imperfection.n.01	defect
# nation.n.02	british
# interruption.n.02	dislocation
# bodily_process.n.01	sex
# military_action.n.01	defense
# method.n.01	technique
# atmospheric_phenomenon.n.01	storm
# cyclone.n.02	hurricane tornado
# neural_structure.n.01	brain
# exile.n.01	refugee
# region.n.01	county
# creation.n.02	art
# military_service.n.01	army
# written_record.n.01	note
# entertainment.n.01	show
# europe.n.01	europe
# know-how.n.01	method
# worker.n.01	employee
# device.n.01	instrument
# act.n.02	activity
# approach.n.01	avenue
# complex.n.01	syndrome
# experiment.n.01	testing
# prosody.n.01	stress
# mercantile_establishment.n.01	store
# temptation.n.01	bait
# measure.n.01	countermeasure
# sound.n.01	ring
# primate.n.02	monkey
# support.n.02	reassurance
# biome.n.01	woodland
# woody_plant.n.01	tree
# lipid.n.01	oil
# administrative_unit.n.01	agency committee
# alluvial_sediment.n.01	delta
# attack.n.01	charge
# pain.n.01	suffering burn
# medium_of_exchange.n.01	money
# season.n.02	summer autumn fall
# political_orientation.n.01	democracy
# food.n.02	beef poultry
# social_group.n.01	organization society
# james.n.01	james
# orientation.n.02	ideology
# outgo.n.01	cost
# position.n.01	post
# movement.n.03	wave
# tract.n.01	site common field
# commodity.n.01	product
# duty.n.02	role
# sacred_text.n.01	gospel
# ordering.n.01	genome
# agent.n.03	drug
# pony.n.01	mustang
# animal_tissue.n.01	transplant
# explorer.n.01	diver
# contestant.n.01	athlete
# social_control.n.01	responsibility
# ability.n.02	skill
# disorder.n.01	ailment
# motion.n.06	travel
# parent.n.01	father
# congregation.n.01	flock
# animal.n.01	male pet
# small_indefinite_quantity.n.01	bit handful
# child.n.01	preschooler
# soil.n.02	sand topsoil
# work.n.01	service
# deterioration.n.01	devastation
# poultry.n.02	chicken
# ball_game.n.01	baseball
# expanse.n.03	stretch
# serviceman.n.01	veteran
# receptacle.n.01	hopper
# contact.n.04	impact
# assets.n.01	amount
# natural_science.n.01	chemistry
# indefinite_quantity.n.01	worth
# instrumentality.n.03	equipment medium system
# failure.n.02	malfunction
# line.n.01	row
# endurance.n.01	tolerance
# component.n.01	point
# ovum.n.01	egg
# fundamental_quantity.n.01	mass period
# associate_degree.n.01	an
# growth.n.06	tumor
# waste.n.01	wastewater
# wetland.n.01	marsh
# sexual_activity.n.01	promiscuity
# plan.n.01	regimen
# denial.n.01	negative
# choice.n.02	sampling
# sequence.n.01	gene
# builder.n.03	contractor
# earth.n.02	dirt
# princeton.n.01	princeton
# danger.n.01	vulnerability
# mann.n.01	mann
# educator.n.01	teacher instructor
# disorder.n.03	confusion
# highjacker.n.02	footpad
# feature.n.01	aspect
# floor_cover.n.01	mat
# plant_organ.n.01	root
# american.n.01	badger
# soldier.n.01	peacekeeper
# drunkard.n.01	alcoholic
# drug_addiction.n.01	alcoholism
# mania.n.02	hysteria
# rain.n.01	torrent
# category.n.02	kind
# treatment.n.01	acupuncture
# insertion.n.02	transfusion
# rate.n.01	speed
# extracellular_fluid.n.01	plasma
# brain_disorder.n.01	cjd
# process.n.06	phenomenon
# danger.n.03	risk threat
# enterprise.n.02	business
# lepidopterous_insect.n.01	butterfly
# acknowledgment.n.03	handshake
# fatness.n.01	obesity
# action.n.01	resistance
# document.n.01	report
# hope.n.02	optimism
# number.n.01	majority
# geological_formation.n.01	beach
# area.n.01	center
# lover.n.01	boyfriend
# temperature.n.02	warmth
# power.n.01	effectiveness
# migrant.n.01	settler
# organic_process.n.01	aging
# polymer.n.01	dna
# law.n.02	constitution
# drug.n.01	medication
# attribute.n.02	quality trait
# grain.n.07	rye
# line.n.18	cord
# ill-being.n.01	misery
# china.n.01	china
# excavation.n.03	well
# matter.n.03	substance
# hindu.n.02	swami
# ross.n.01	ross
# proceeding.n.01	lawsuit
# johnson.n.01	johnson
# musical_performance.n.01	singing
# articulator.n.01	speaker
# practitioner.n.01	clinician
# candidiasis.n.01	thrush
# institution.n.01	company
# interpretation.n.03	version
# williams.n.01	williams
# antimalarial.n.01	chloroquine
# benefactor.n.01	donor
# intensification.n.01	exacerbation
# vagrant.n.01	tramp
# present.n.01	today
# connection.n.06	node
# nervous_disorder.n.01	encephalopathy
# educational_institution.n.01	school
# india.n.01	india
# swift.n.01	swift
# cardiovascular_disease.n.01	aneurysm
# frequency.n.02	incidence
# woman.n.01	prostitute girl
# sexual_relationship.n.01	liaison
# imagination.n.01	fantasy
# pessimism.n.01	cynicism
# asian.n.01	oriental
# communicable_disease.n.01	cold
# evidence.n.02	argument
# nile.n.01	nile
# projection.n.05	extrusion
# koch.n.01	koch
# higher_cognitive_process.n.01	thinking
# situation.n.03	crisis
# nongovernmental_organization.n.01	mission
# disturbance.n.05	havoc
# experience.n.02	living
# roll_of_tobacco.n.01	cigarette
# aggression.n.03	violence
# possibility.n.02	chance
# improvement.n.02	development
# mutuality.n.02	sharing
# shrub.n.01	tamarisk
# military_installation.n.01	base
# walker.n.01	walker
# female_offspring.n.01	daughter
# case.n.05	portfolio
# edward.n.01	edward
# extremity.n.05	hand
# fossil.n.02	microfossil
# creating_by_removal.n.01	drilling
# communicator.n.01	author
# site.n.01	cemetery
# anti-tnf_compound.n.01	enbrel
# neurotransmitter.n.01	acetylcholine
# motivation.n.01	impulse
# chemical_process.n.01	mechanism
# hit.n.02	bunt
# customer.n.01	buyer
# weather.n.01	wind
# degree.n.02	extent
# advantage.n.01	good
# spot.n.05	speck
# shore.n.01	coast
# employee.n.01	bartender
# friend.n.01	companion
# health_professional.n.01	nurse
# capitalist.n.02	investor
# rank.n.02	first
# elasticity.n.01	resilience
# west_germanic.n.01	english
# product.n.02	movie
# cleaning.n.01	sweeping
# particulate.n.01	dust
# association.n.01	institute
# syndrome.n.02	autism
# sweet.n.03	gum
# inference.n.01	implication
# grandparent.n.01	grandfather
# decay.n.04	rot
# part.n.01	rest
# hudson.n.01	hudson
# belief.n.01	philosophy
# newspaper.n.01	daily
# baby.n.01	newborn

# %%
generalized_terms['adult.n.01']
# Out:
# {'host', 'man', 'woman'}

# %%
for i in wn.synsets('state'):
    print(i, i.definition(), i.hypernyms(), i.root_hypernyms())
# Out:
# Synset('state.n.01') the territory occupied by one of the constituent administrative districts of a nation [Synset('administrative_district.n.01')] [Synset('entity.n.01')]
# Synset('state.n.02') the way something is with respect to its main attributes [Synset('attribute.n.02')] [Synset('entity.n.01')]
# Synset('state.n.03') the group of people comprising the government of a sovereign state [Synset('government.n.01')] [Synset('entity.n.01')]
# Synset('state.n.04') a politically organized body of people under a single government [Synset('political_unit.n.01')] [Synset('entity.n.01')]
# Synset('state_of_matter.n.01') (chemistry) the three traditional states of matter are solids (fixed shape and volume) and liquids (fixed volume and shaped by the container) and gases (filling the container) [Synset('chemical_phenomenon.n.01')] [Synset('entity.n.01')]
# Synset('state.n.06') a state of depression or agitation [Synset('emotional_state.n.01')] [Synset('entity.n.01')]
# Synset('country.n.02') the territory occupied by a nation [Synset('administrative_district.n.01')] [Synset('entity.n.01')]
# Synset('department_of_state.n.01') the federal department in the United States that sets and maintains foreign policies [Synset('executive_department.n.01')] [Synset('entity.n.01')]
# Synset('state.v.01') express in words [Synset('express.v.02')] [Synset('express.v.02')]
# Synset('submit.v.02') put before [Synset('propose.v.01')] [Synset('express.v.02')]
# Synset('express.v.04') indicate through a symbol, formula, etc. [Synset('denote.v.02')] [Synset('mean.v.03')]

# %% [markdown]
# ---
