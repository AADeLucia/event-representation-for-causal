# %% [markdown]
# * https://www.nltk.org/howto/wordnet.html

# %%
import nltk
import jsonlines
import collections
import os
import json
from nltk.corpus import wordnet as wn
from collections import Counter

lemmatizer = nltk.stem.WordNetLemmatizer()

# %%
synsets = {
    "protests": {
        "police": wn.synset('law_enforcement_agency.n.01').name(),
        "bush": wn.synset('politician.n.02').name(),
        "putin": wn.synset('politician.n.02').name(),
        "hussein": wn.synset('politician.n.02').name(),
        "hizballah": wn.synset('politician.n.02').name(),
        "hezbollah": wn.synset('politician.n.02').name(),
        "gore": wn.synset('politician.n.02').name(),
        "politician": wn.synset('politician.n.02').name(),
        "gore": wn.synset('politician.n.02').name(),
        
        "city": wn.synset('urban_area.n.01').name(),
        "broadway": wn.synset('urban_area.n.01').name(),
        "orleans": wn.synset('urban_area.n.01').name(),
        "tokyo": wn.synset('urban_area.n.01').name(),
        "selma": wn.synset('urban_area.n.01').name(),
        "guadalajara": wn.synset('urban_area.n.01').name(),
        "paris": wn.synset('urban_area.n.01').name(),
        "zaragoza": wn.synset('urban_area.n.01').name(),
        "beijing": wn.synset('urban_area.n.01').name(),
        "washington": wn.synset('urban_area.n.01').name(),
        "zaragoza": wn.synset('urban_area.n.01').name(),
        
        "demonstrator": wn.synset('reformer.n.01').name(),
        "protester": wn.synset('reformer.n.01').name(),
        "demonstration": wn.synset('protest.n.02').name(),
        "protest": wn.synset('protest.n.02').name(),
        "sit-in": wn.synset('protest.n.02').name(),
        "march": wn.synset('protest.n.02').name(),
        "rally": wn.synset('protest.n.02').name(),
        
        "woman": wn.synset('person.n.01').name(),
        "man": wn.synset('person.n.01').name(),
        "daughter": wn.synset('person.n.01').name(),
        "student": wn.synset('person.n.01').name(),
        "group": wn.synset('group.n.01').name(),

        "japan": wn.synset('political_unit.n.01').name(),
        "china": wn.synset('political_unit.n.01').name(),
        "israel": wn.synset('political_unit.n.01').name(),
        "isreal": wn.synset('political_unit.n.01').name(),
        "egypt": wn.synset('political_unit.n.01').name(),
        "lithuania": wn.synset('political_unit.n.01').name(),
        "lebanon": wn.synset('political_unit.n.01').name(),
        "haiti": wn.synset('political_unit.n.01').name(),
        "fiji": wn.synset('political_unit.n.01').name(),
        "nigeria": wn.synset('political_unit.n.01').name(),
        "cuba": wn.synset('political_unit.n.01').name(),
        "iraq": wn.synset('political_unit.n.01').name(),
        "uganda": wn.synset('political_unit.n.01').name(),
        "cuba": wn.synset('political_unit.n.01').name(),
        "cuba": wn.synset('political_unit.n.01').name(),
        "cuba": wn.synset('political_unit.n.01').name(),
        "cuba": wn.synset('political_unit.n.01').name(),
    },
    "disease_outbreak": {
        "organism": wn.synset('organism.n.01').name(),
        "fly": wn.synset('organism.n.01').name(),
        "cat": wn.synset('organism.n.01').name(),
        "rat": wn.synset('organism.n.01').name(),
        "mosquito": wn.synset('organism.n.01').name(),
        "cattle": wn.synset('organism.n.01').name(),
        "bird": wn.synset('organism.n.01').name(),
        "mouse": wn.synset('organism.n.01').name(),
        "gorilla": wn.synset('organism.n.01').name(),
        "deer": wn.synset('organism.n.01').name(),
        "horse": wn.synset('organism.n.01').name(),
        "worm": wn.synset('organism.n.01').name(),
        "bat": wn.synset('organism.n.01').name(),
        "sheep": wn.synset('organism.n.01').name(),
        "cow": wn.synset('organism.n.01').name(),
        "dog": wn.synset('organism.n.01').name(),
        "livestock": wn.synset('organism.n.01').name(),
        "bison": wn.synset('organism.n.01').name(),
        "duck": wn.synset('organism.n.01').name(),
        "frog": wn.synset('organism.n.01').name(),
        "chimpanzee": wn.synset('organism.n.01').name(),
        "pigeon": wn.synset('organism.n.01').name(),
        "swan": wn.synset('organism.n.01').name(),
        "shellfish": wn.synset('organism.n.01').name(),
        "pig": wn.synset('organism.n.01').name(),
        "salmon": wn.synset('organism.n.01').name(),
        "trout": wn.synset('organism.n.01').name(),
        "tick": wn.synset('organism.n.01').name(),
        "fish": wn.synset('organism.n.01').name(),
        "ferret": wn.synset('organism.n.01').name(),
        "rodent": wn.synset('organism.n.01').name(),
        "gerbil": wn.synset('organism.n.01').name(),
        "hamster": wn.synset('organism.n.01').name(),
        "raccoon": wn.synset('organism.n.01').name(),
        "lion": wn.synset('organism.n.01').name(),
        "crab": wn.synset('organism.n.01').name(),
        "elk": wn.synset('organism.n.01').name(),
        "mammal": wn.synset('organism.n.01').name(),
        "toad": wn.synset('organism.n.01').name(),
        "salmon": wn.synset('organism.n.01').name(),
        
        "poultry": wn.synset('food.n.02').name(),
        "beef": wn.synset('food.n.02').name(),
                
        "mumps": wn.synset('illness.n.01').name(),
        "meningitis": wn.synset('illness.n.01').name(),
        "polio": wn.synset('illness.n.01').name(),
        "tuberculosis": wn.synset('illness.n.01').name(),
        "dysentery": wn.synset('illness.n.01').name(),
        "leprosy": wn.synset('illness.n.01').name(),
        "cholera": wn.synset('illness.n.01').name(),
        "herpes": wn.synset('illness.n.01').name(),
        "fibrosis": wn.synset('illness.n.01').name(),
        "osteoporosis": wn.synset('illness.n.01').name(),
        "sclerosis": wn.synset('illness.n.01').name(),
        "influenza": wn.synset('illness.n.01').name(),
        "flu": wn.synset('illness.n.01').name(),
        "sickness": wn.synset('illness.n.01').name(),
        "infection": wn.synset('illness.n.01').name(),
        "illness": wn.synset('illness.n.01').name(),
        "injury": wn.synset('illness.n.01').name(),
        "leukemia": wn.synset('illness.n.01').name(),
        "carcinoma": wn.synset('illness.n.01').name(),
        "hiv": wn.synset('illness.n.01').name(),
        "asbestosis": wn.synset('illness.n.01').name(),
        "smallpox": wn.synset('illness.n.01').name(),
        "rabies": wn.synset('illness.n.01').name(),
        "anemia": wn.synset('illness.n.01').name(),
        "encephalitis": wn.synset('illness.n.01').name(),
        "zoonosis": wn.synset('illness.n.01').name(),
        "rinderpest": wn.synset('illness.n.01').name(),
        "bse": wn.synset('illness.n.01').name(),
        "osteoarthritis": wn.synset('illness.n.01').name(),
        "sepsis": wn.synset('illness.n.01').name(),
        "cancer": wn.synset('illness.n.01').name(),
        "trachoma": wn.synset('illness.n.01').name(),
        "malaria": wn.synset('illness.n.01').name(),
        "melanoma": wn.synset('illness.n.01').name(),
        "angioma": wn.synset('illness.n.01').name(),
        "plague": wn.synset('illness.n.01').name(),
        "sars": wn.synset('illness.n.01').name(),
        "pneumonia": wn.synset('illness.n.01').name(),
        "parkinson": wn.synset('illness.n.01').name(),
        "psoriasis": wn.synset('illness.n.01').name(),
        "arthritis": wn.synset('illness.n.01').name(),
        "mucopolysaccharidosis": wn.synset('illness.n.01').name(),
        "gonorrhea": wn.synset('illness.n.01').name(),
        "plague": wn.synset('illness.n.01').name(),
        "plague": wn.synset('illness.n.01').name(),
        "plague": wn.synset('illness.n.01').name(),
        "plague": wn.synset('illness.n.01').name(),
   
        "intestine": wn.synset('body_part.n.01').name(),
        "liver": wn.synset('body_part.n.01').name(),
        "lung": wn.synset('body_part.n.01').name(),
        "heart": wn.synset('body_part.n.01').name(),
        "lung": wn.synset('body_part.n.01').name(),
        "lung": wn.synset('body_part.n.01').name(),
        "lung": wn.synset('body_part.n.01').name(),
        "lung": wn.synset('body_part.n.01').name(),

        "bacillus": wn.synset('infectious_agent.n.01').name(),
        "spirochete": wn.synset('infectious_agent.n.01').name(),
        "microbe": wn.synset('infectious_agent.n.01').name(),
        "bacteria": wn.synset('infectious_agent.n.01').name(),
        "bacterium": wn.synset('infectious_agent.n.01').name(),
        "bacillus": wn.synset('infectious_agent.n.01').name(),
                
    },
    "election": {
        "bush": wn.synset('campaigner.n.01').name(),
        "gore": wn.synset('campaigner.n.01').name(),
        "clinton": wn.synset('campaigner.n.01').name(),
        "nixon": wn.synset('campaigner.n.01').name(),
        "bush": wn.synset('campaigner.n.01').name(),
        
        "conservative": wn.synset('political_orientation.n.01').name(),
        "liberal": wn.synset('political_orientation.n.01').name(),
        "moderate": wn.synset('political_orientation.n.01').name(),
        "nationalist": wn.synset('political_orientation.n.01').name(),
        "center": wn.synset('political_orientation.n.01').name(),
        "middle": wn.synset('political_orientation.n.01').name(),
        "left": wn.synset('political_orientation.n.01').name(),
        "right": wn.synset('political_orientation.n.01').name(),
        "center": wn.synset('political_orientation.n.01').name(),

    },
    "arrest": {
        "murder": wn.synset('crime.n.01').name(),
        "smuggling": wn.synset('crime.n.01').name(),
        "intimidation": wn.synset('crime.n.01').name(),
        "assault": wn.synset('crime.n.01').name(),
        "scam": wn.synset('crime.n.01').name(),
        "kidnapping": wn.synset('crime.n.01').name(),
        "killing": wn.synset('crime.n.01').name(),
        
        "trafficker": wn.synset('criminal.n.01').name(),
        "dealer": wn.synset('criminal.n.01').name(),
        "shoplifter": wn.synset('criminal.n.01').name(),
        "rioter": wn.synset('criminal.n.01').name(),
        "troublemaker": wn.synset('criminal.n.01').name(),
        "plotter": wn.synset('criminal.n.01').name(),
        "abductor": wn.synset('criminal.n.01').name(),
        "offender": wn.synset('criminal.n.01').name(),
        "hijacker": wn.synset('criminal.n.01').name(),
        "rapist": wn.synset('criminal.n.01').name(),
        "stoner": wn.synset('criminal.n.01').name(),
        "predator": wn.synset('criminal.n.01').name(),
        "felon": wn.synset('criminal.n.01').name(),
        "criminal": wn.synset('criminal.n.01').name(),
        "pimp": wn.synset('criminal.n.01').name(),
        "abuser": wn.synset('criminal.n.01').name(),
        "attacker": wn.synset('criminal.n.01').name(),
        "perpetrator": wn.synset('criminal.n.01').name(),
        "pedophile": wn.synset('criminal.n.01').name(),
        "flasher": wn.synset('criminal.n.01').name(),
        "flasher": wn.synset('criminal.n.01').name(),
        "flasher": wn.synset('criminal.n.01').name(),
        "flasher": wn.synset('criminal.n.01').name(),
        "flasher": wn.synset('criminal.n.01').name(),

        "police": wn.synset('law_enforcement_agency.n.01').name(),
        "bush": wn.synset('politician.n.02').name(),

        "syria": wn.synset('political_unit.n.01').name(),
        "iraq": wn.synset('political_unit.n.01').name(),
        "yugoslavia": wn.synset('political_unit.n.01').name(),
        "zagreb": wn.synset('political_unit.n.01').name(),
        "nato": wn.synset('political_unit.n.01').name(),
        "europe": wn.synset('political_unit.n.01').name(),
        "eritrea": wn.synset('political_unit.n.01').name(),
        "lebanon": wn.synset('political_unit.n.01').name(),
        "haiti": wn.synset('political_unit.n.01').name(),
        "fiji": wn.synset('political_unit.n.01').name(),
        "nigeria": wn.synset('political_unit.n.01').name(),
        "cuba": wn.synset('political_unit.n.01').name(),
        "uganda": wn.synset('political_unit.n.01').name(),
        "pakistan": wn.synset('political_unit.n.01').name(),
        "iran": wn.synset('political_unit.n.01').name(),
        "belgium": wn.synset('political_unit.n.01').name(),
        "spain": wn.synset('political_unit.n.01').name(),
        "bengal": wn.synset('political_unit.n.01').name(),
        "spain": wn.synset('political_unit.n.01').name(),
        "spain": wn.synset('political_unit.n.01').name(),
        
        "diplomat": wn.synset('politician.n.02').name(),
        "vargas": wn.synset('politician.n.02').name(),
        "putin": wn.synset('politician.n.02').name(),
        "chiluba": wn.synset('politician.n.02').name(),
        "president": wn.synset('politician.n.02').name(),
        "vargas": wn.synset('politician.n.02').name(),
        "vargas": wn.synset('politician.n.02').name(),
        "vargas": wn.synset('politician.n.02').name(),
        "vargas": wn.synset('politician.n.02').name(),
        
    },
    "plane_crash": {
        "plane": wn.synset('airplane.n.01').name(),
        "helicopter": wn.synset('airplane.n.01').name(),
        "sailplane": wn.synset('airplane.n.01').name(),
        "airplane": wn.synset('airplane.n.01').name(),
        "glider": wn.synset('airplane.n.01').name(),
        "warplane": wn.synset('airplane.n.01').name(),
        "jetliner": wn.synset('airplane.n.01').name(),
        "aircraft": wn.synset('airplane.n.01').name(),
        "turboprop": wn.synset('airplane.n.01').name(),
        "warplane": wn.synset('airplane.n.01').name(),
        "warplane": wn.synset('airplane.n.01').name(),
        "warplane": wn.synset('airplane.n.01').name(),
    }
}

stopwords = {"we", "they", "who", "which", "that", "i", "it", "he", "she", "them", "him", "her", "u", "me", "a"}

# %%
schema = "arrest"

# Load key verbs
with open("/srv/local2/adeluci2/event-representation-for-causal/results/schema_verbs.json") as f:
    key_verbs = set(json.load(f)[schema])

common_preds_args = Counter()
common_args = Counter()
generalized_terms = {}
related_docs = f"/srv/local2/adeluci2/event-representation-for-causal/results/{schema}/nyt_en_{schema}.jsonl.predargs"


with jsonlines.open(related_docs) as reader:
    for obj in reader.iter():
        for pred_args in obj['pred_args']:
            pred_idx = pred_args[2]
            arg_idx = 1 - pred_idx
            pred, arg = pred_args[pred_idx], pred_args[arg_idx].lower()
            arg = lemmatizer.lemmatize(arg, pos=wn.NOUN)
            if pred not in key_verbs or arg.lower() in stopwords:
                continue
            
            # Check if word is in the custom synset list
            # Use WordNet lookup if not
            if arg in synsets[schema]:
                syn_root = synsets[schema][arg]
            else:
                if not wn.synsets(arg, pos=wn.NOUN):
                    continue
                syn = wn.synsets(arg, pos=wn.NOUN)[0]
                if syn.hypernyms():
                    syn_root = syn.hypernyms()[0].name()
                else:
                    syn_root = syn.name()
            common_preds_args.update([(pred, syn_root, pred_idx)])
            common_args.update([arg])
            generalized_terms[syn_root] = generalized_terms.get(syn_root, set())
            generalized_terms[syn_root].add(arg)
            
            # print(f"Pred: {pred}\tArg: {arg}\t{syn_root}")

# %%
common_preds_args.most_common()
# Out:
# [(('arrest', 'law_enforcement_agency.n.01', 1), 1011),
#  (('arrest', 'person.n.01', 0), 636),
#  (('arrest', 'group.n.01', 0), 203),
#  (('face', 'attack.n.01', 0), 124),
#  (('arrest', 'control.n.01', 1), 124),
#  (('arrest', 'adult.n.01', 0), 118),
#  (('arrest', 'force.n.04', 0), 108),
#  (('arrest', 'associate.n.01', 0), 69),
#  (('arrest', 'serviceman.n.01', 1), 62),
#  (('arrest', 'criminal.n.01', 0), 59),
#  (('arrest', 'digit.n.01', 0), 59),
#  (('arrest', 'causal_agent.n.01', 1), 51),
#  (('accuse', 'law_enforcement_agency.n.01', 0), 50),
#  (('arrest', 'causal_agent.n.01', 0), 46),
#  (('charge', 'law_enforcement_agency.n.01', 1), 46),
#  (('arrest', 'large_integer.n.01', 0), 37),
#  (('charge', 'lawyer.n.01', 1), 36),
#  (('face', 'social_control.n.01', 0), 33),
#  (('arrest', 'lawyer.n.01', 1), 31),
#  (('arrest', 'administrator.n.01', 0), 28),
#  (('arrest', 'enrollee.n.01', 0), 26),
#  (('arrest', 'case.n.01', 0), 26),
#  (('arrest', 'influence.n.01', 1), 26),
#  (('arrest', 'policeman.n.01', 1), 22),
#  (('arrest', 'polity.n.02', 1), 22),
#  (('charge', 'control.n.01', 1), 21),
#  (('face', 'string_of_words.n.01', 0), 21),
#  (('arrest', 'scientist.n.01', 1), 21),
#  (('arrest', 'reformer.n.01', 0), 20),
#  (('arrest', 'juvenile.n.01', 0), 20),
#  (('arrest', 'skilled_worker.n.01', 1), 19),
#  (('indict', 'criminal.n.01', 0), 18),
#  (('arrest', 'parent.n.01', 0), 17),
#  (('convict', 'body.n.02', 1), 16),
#  (('accuse', 'polity.n.02', 0), 16),
#  (('accuse', 'person.n.01', 1), 15),
#  (('arrest', 'pair.n.03', 0), 14),
#  (('face', 'person.n.01', 1), 14),
#  (('arrest', 'migrant.n.01', 0), 14),
#  (('arrest', 'army_unit.n.01', 1), 14),
#  (('face', 'danger.n.03', 0), 12),
#  (('plead', 'social_event.n.01', 0), 12),
#  (('face', 'attempt.n.01', 0), 12),
#  (('charge', 'person.n.01', 0), 12),
#  (('face', 'number.n.02', 0), 12),
#  (('arrest', 'skilled_worker.n.01', 0), 12),
#  (('arrest', 'politician.n.02', 0), 12),
#  (('arrest', 'political_unit.n.01', 1), 11),
#  (('indict', 'assembly.n.04', 1), 11),
#  (('arrest', 'serviceman.n.01', 0), 11),
#  (('accuse', 'adult.n.01', 1), 11),
#  (('arrest', 'digit.n.01', 1), 11),
#  (('accuse', 'law_enforcement_agency.n.01', 1), 11),
#  (('accuse', 'lawyer.n.01', 1), 11),
#  (('indict', 'person.n.01', 0), 11),
#  (('arrest', 'operator.n.02', 0), 11),
#  (('arrest', 'spouse.n.01', 0), 10),
#  (('face', 'polity.n.02', 1), 10),
#  (('arrest', 'traveler.n.01', 0), 10),
#  (('charge', 'adult.n.01', 0), 10),
#  (('indict', 'slav.n.01', 0), 10),
#  (('arrest', 'williams.n.01', 0), 10),
#  (('accuse', 'skilled_worker.n.01', 1), 9),
#  (('arrest', 'inhabitant.n.01', 0), 9),
#  (('charge', 'group.n.01', 0), 8),
#  (('arrest', 'activity.n.01', 1), 8),
#  (('accuse', 'control.n.01', 1), 8),
#  (('arrest', 'asian.n.01', 0), 8),
#  (('accuse', 'professional.n.01', 1), 8),
#  (('testify', 'perceiver.n.01', 1), 7),
#  (('arrest', 'arab.n.01', 1), 7),
#  (('arrest', 'radical.n.03', 0), 7),
#  (('face', 'situation.n.01', 0), 7),
#  (('charge', 'digit.n.01', 0), 7),
#  (('face', 'serviceman.n.01', 1), 7),
#  (('arrest', 'male.n.02', 0), 7),
#  (('face', 'extremum.n.02', 0), 7),
#  (('accuse', 'political_unit.n.01', 0), 7),
#  (('arrest', 'writ.n.01', 0), 7),
#  (('arrest', 'law_enforcement_agency.n.01', 0), 7),
#  (('testify', 'serviceman.n.01', 1), 7),
#  (('arrest', 'leader.n.01', 0), 7),
#  (('charge', 'force.n.04', 0), 7),
#  (('arrest', 'male_sibling.n.01', 0), 7),
#  (('arrest', 'time_unit.n.01', 0), 7),
#  (('arrest', 'arab.n.01', 0), 6),
#  (('charge', 'professional.n.01', 1), 6),
#  (('arrest', 'time_unit.n.01', 1), 6),
#  (('accuse', 'person.n.01', 0), 6),
#  (('arrest', 'lawman.n.01', 1), 6),
#  (('face', 'action.n.01', 0), 6),
#  (('face', 'natural_virtue.n.01', 0), 6),
#  (('face', 'physical_phenomenon.n.01', 0), 6),
#  (('indict', 'body.n.02', 1), 6),
#  (('indict', 'causal_agent.n.01', 0), 6),
#  (('arrest', 'force.n.04', 1), 6),
#  (('face', 'being.n.01', 0), 6),
#  (('plead', 'adult.n.01', 1), 6),
#  (('indict', 'lawyer.n.01', 1), 6),
#  (('arrest', 'person.n.01', 1), 6),
#  (('testify', 'law_enforcement_agency.n.01', 1), 6),
#  (('arrest', 'time_period.n.01', 0), 6),
#  (('arrest', 'woman.n.01', 0), 6),
#  (('arrest', 'businessman.n.01', 0), 6),
#  (('arrest', 'illustration.n.01', 0), 6),
#  (('face', 'litigant.n.01', 1), 6),
#  (('face', 'legal_action.n.01', 0), 6),
#  (('arrest', 'weekday.n.01', 0), 6),
#  (('sentence', 'adjudicator.n.01', 1), 5),
#  (('plead', 'digit.n.01', 1), 5),
#  (('face', 'digit.n.01', 1), 5),
#  (('arrest', 'worker.n.01', 0), 5),
#  (('charge', 'scientist.n.01', 1), 5),
#  (('arrest', 'teacher.n.01', 0), 5),
#  (('arrest', 'jones.n.01', 0), 5),
#  (('charge', 'assembly.n.04', 1), 5),
#  (('arrest', 'thinker.n.02', 0), 5),
#  (('face', 'crime.n.01', 0), 5),
#  (('face', 'proceeding.n.01', 0), 5),
#  (('accuse', 'politician.n.02', 0), 5),
#  (('face', 'inquiry.n.01', 0), 5),
#  (('face', 'law_enforcement_agency.n.01', 1), 5),
#  (('face', 'disapproval.n.02', 0), 5),
#  (('accuse', 'criminal.n.01', 1), 5),
#  (('plead', 'spouse.n.01', 1), 5),
#  (('arrest', 'evaluation.n.02', 0), 5),
#  (('accuse', 'criminal.n.01', 0), 5),
#  (('convict', 'assembly.n.04', 1), 5),
#  (('face', 'time_period.n.01', 0), 5),
#  (('arrest', 'muhammad.n.01', 0), 5),
#  (('charge', 'polity.n.02', 1), 5),
#  (('face', 'banishment.n.02', 0), 5),
#  (('face', 'political_unit.n.01', 1), 4),
#  (('accuse', 'abstraction.n.06', 1), 4),
#  (('testify', 'adult.n.01', 1), 4),
#  (('arrest', 'division.n.04', 1), 4),
#  (('arrest', 'male_offspring.n.01', 0), 4),
#  (('arrest', 'chromatic_color.n.01', 0), 4),
#  (('testify', 'digit.n.01', 1), 4),
#  (('arrest', 'power.n.01', 1), 4),
#  (('charge', 'function.n.01', 0), 4),
#  (('charge', 'associate.n.01', 0), 4),
#  (('face', 'municipality.n.01', 1), 4),
#  (('accuse', 'adult.n.01', 0), 4),
#  (('face', 'word.n.01', 0), 4),
#  (('arrest', 'association.n.01', 0), 4),
#  (('arrest', 'proportion.n.01', 0), 4),
#  (('accuse', 'legal_document.n.01', 1), 4),
#  (('arrest', 'control.n.01', 0), 4),
#  (('accuse', 'attack.n.01', 1), 4),
#  (('arrest', 'linear_unit.n.01', 0), 4),
#  (('face', 'maltreatment.n.01', 0), 4),
#  (('charge', 'place_of_business.n.01', 1), 4),
#  (('face', 'penalty.n.02', 0), 4),
#  (('arrest', 'enlisted_person.n.01', 0), 4),
#  (('charge', 'juvenile.n.01', 0), 4),
#  (('arrest', 'blair.n.01', 0), 4),
#  (('plead', 'blair.n.01', 1), 4),
#  (('arrest', 'miller.n.01', 0), 4),
#  (('arrest', 'perceiver.n.01', 0), 4),
#  (('face', 'assembly.n.04', 1), 4),
#  (('face', 'potential.n.01', 0), 4),
#  (('face', 'criminal.n.01', 1), 4),
#  (('face', 'surrender.n.03', 0), 4),
#  (('arrest', 'amount.n.02', 0), 4),
#  (('arrest', 'administrative_unit.n.01', 1), 4),
#  (('accuse', 'politician.n.02', 1), 4),
#  (('arrest', 'military_officer.n.01', 0), 4),
#  (('arrest', 'enlisted_person.n.01', 1), 4),
#  (('plead', 'crime.n.01', 0), 4),
#  (('accuse', 'digit.n.01', 0), 4),
#  (('arrest', 'extent.n.02', 0), 4),
#  (('arrest', 'man.n.01', 0), 4),
#  (('testify', 'person.n.01', 1), 4),
#  (('arrest', 'asian.n.01', 1), 4),
#  (('arrest', 'contestant.n.01', 0), 4),
#  (('sentence', 'western_malayo-polynesian.n.01', 1), 4),
#  (('sentence', 'time_unit.n.01', 0), 4),
#  (('sentence', 'mitchell.n.01', 0), 4),
#  (('face', 'group.n.01', 1), 4),
#  (('face', 'information.n.02', 0), 4),
#  (('indict', 'slav.n.01', 1), 4),
#  (('face', 'craftsman.n.03', 1), 4),
#  (('testify', 'signaler.n.01', 1), 4),
#  (('arrest', 'small_indefinite_quantity.n.01', 0), 3),
#  (('face', 'approval.n.04', 0), 3),
#  (('plead', 'serviceman.n.01', 1), 3),
#  (('accuse', 'serviceman.n.01', 0), 3),
#  (('accuse', 'attack.n.01', 0), 3),
#  (('charge', 'work.n.01', 0), 3),
#  (('arrest', 'golfer.n.01', 0), 3),
#  (('accuse', 'performer.n.01', 1), 3),
#  (('testify', 'policeman.n.01', 1), 3),
#  (('accuse', 'instrumentality.n.03', 0), 3),
#  (('arrest', 'grandparent.n.01', 0), 3),
#  (('sentence', 'assembly.n.04', 1), 3),
#  (('arrest', 'set.n.01', 0), 3),
#  (('arrest', 'murderer.n.01', 0), 3),
#  (('arrest', 'example.n.01', 0), 3),
#  (('convict', 'person.n.01', 0), 3),
#  (('accuse', 'spouse.n.01', 0), 3),
#  (('plead', 'force.n.04', 1), 3),
#  (('accuse', 'arab.n.01', 1), 3),
#  (('charge', 'enrollee.n.01', 0), 3),
#  (('face', 'legal_document.n.01', 0), 3),
#  (('arrest', 'trainer.n.01', 0), 3),
#  (('accuse', 'skilled_worker.n.01', 0), 3),
#  (('plead', 'case.n.06', 1), 3),
#  (('arrest', 'group.n.01', 1), 3),
#  (('arrest', 'defender.n.01', 0), 3),
#  (('arrest', 'drinker.n.02', 0), 3),
#  (('arrest', 'friend.n.01', 0), 3),
#  (('accuse', 'control.n.01', 0), 3),
#  (('face', 'accusation.n.01', 0), 3),
#  (('charge', 'law_enforcement_agency.n.01', 0), 3),
#  (('accuse', 'leader.n.01', 0), 3),
#  (('arrest', 'businessperson.n.01', 0), 3),
#  (('accuse', 'abstraction.n.06', 0), 3),
#  (('accuse', 'clergyman.n.01', 1), 3),
#  (('arrest', 'associate.n.01', 1), 3),
#  (('accuse', 'organization.n.01', 1), 3),
#  (('face', 'fury.n.01', 0), 3),
#  (('testify', 'causal_agent.n.01', 1), 3),
#  (('arrest', 'unfortunate.n.01', 0), 3),
#  (('charge', 'adult.n.01', 1), 3),
#  (('face', 'category.n.02', 0), 3),
#  (('face', 'adult.n.01', 1), 3),
#  (('face', 'state.n.02', 0), 3),
#  (('face', 'law_enforcement_agency.n.01', 0), 3),
#  (('arrest', 'lover.n.01', 0), 3),
#  (('accuse', 'contestant.n.01', 1), 3),
#  (('charge', 'writing.n.02', 0), 3),
#  (('face', 'situation.n.03', 0), 3),
#  (('arrest', 'time_period.n.01', 1), 3),
#  (('arrest', 'management.n.01', 1), 3),
#  (('charge', 'region.n.01', 1), 3),
#  (('convict', 'digit.n.01', 0), 3),
#  (('face', 'body.n.02', 0), 3),
#  (('face', 'causal_agent.n.01', 1), 3),
#  (('testify', 'partition.n.01', 1), 3),
#  (('arrest', 'negotiator.n.01', 0), 3),
#  (('accuse', 'polity.n.02', 1), 3),
#  (('charge', 'lover.n.01', 0), 3),
#  (('arrest', 'domestic_partner.n.01', 0), 3),
#  (('acquit', 'assembly.n.04', 1), 3),
#  (('accuse', 'associate.n.01', 1), 3),
#  (('charge', 'skilled_worker.n.01', 1), 3),
#  (('accuse', 'radical.n.03', 0), 3),
#  (('arrest', 'professional.n.01', 0), 3),
#  (('accuse', 'muslim.n.01', 1), 3),
#  (('charge', 'adjudicator.n.01', 1), 3),
#  (('face', 'pain.n.01', 1), 3),
#  (('arrest', 'semite.n.01', 0), 3),
#  (('testify', 'spectator.n.01', 1), 3),
#  (('charge', 'male_sibling.n.01', 0), 3),
#  (('arrest', 'abstraction.n.06', 1), 3),
#  (('accuse', 'group.n.01', 1), 3),
#  (('convict', 'andersen.n.01', 0), 2),
#  (('face', 'andersen.n.01', 1), 2),
#  (('face', 'institution.n.01', 0), 2),
#  (('face', 'male.n.02', 1), 2),
#  (('arrest', 'psychological_state.n.01', 0), 2),
#  (('acquit', 'body.n.02', 1), 2),
#  (('charge', 'recognizance.n.01', 0), 2),
#  (('face', 'digit.n.01', 0), 2),
#  (('arrest', 'activity.n.01', 0), 2),
#  (('accuse', 'unfortunate.n.01', 1), 2),
#  (('accuse', 'organization.n.01', 0), 2),
#  (('convict', 'causal_agent.n.01', 0), 2),
#  (('arrest', 'santiago_de_los_caballeros.n.01', 0), 2),
#  (('arrest', 'simpson.n.01', 0), 2),
#  (('accuse', 'garment.n.01', 1), 2),
#  (('face', 'williams.n.01', 1), 2),
#  (('accuse', 'jewel.n.01', 0), 2),
#  (('face', 'act.n.02', 0), 2),
#  (('face', 'difficulty.n.03', 0), 2),
#  (('convict', 'example.n.01', 1), 2),
#  (('arrest', 'content.n.05', 0), 2),
#  (('accuse', 'adjudicator.n.01', 1), 2),
#  (('convict', 'force.n.04', 0), 2),
#  (('arrest', 'penetration.n.01', 1), 2),
#  (('sentence', 'digit.n.01', 0), 2),
#  (('charge', 'causal_agent.n.01', 0), 2),
#  (('arrest', 'place_of_business.n.01', 1), 2),
#  (('indict', 'digit.n.01', 0), 2),
#  (('arrest', 'joseph.n.01', 0), 2),
#  (('face', 'gathering.n.01', 0), 2),
#  (('arrest', 'more.n.01', 0), 2),
#  (('arrest', 'protestant.n.01', 0), 2),
#  (('charge', 'chromatic_color.n.01', 0), 2),
#  (('charge', 'administrator.n.01', 0), 2),
#  (('charge', 'legal_document.n.01', 1), 2),
#  (('accuse', 'georgia.n.01', 1), 2),
#  (('face', 'insufficiency.n.03', 0), 2),
#  (('face', 'movable_barrier.n.01', 0), 2),
#  (('arrest', 'yankee.n.01', 1), 2),
#  (('arrest', 'genitor.n.01', 0), 2),
#  (('accuse', 'slav.n.01', 1), 2),
#  (('charge', 'capture.n.01', 1), 2),
#  (('face', 'inhabitant.n.01', 1), 2),
#  (('face', 'force.n.04', 1), 2),
#  (('face', 'structure.n.01', 0), 2),
#  (('charge', 'businessperson.n.01', 0), 2),
#  (('arrest', 'workman.n.01', 0), 2),
#  (('arrest', 'attraction.n.01', 0), 2),
#  (('arrest', 'father_figure.n.01', 0), 2),
#  (('face', 'cord.n.01', 0), 2),
#  (('testify', 'adjudicator.n.01', 1), 2),
#  (('arrest', 'johnson.n.01', 0), 2),
#  (('arrest', 'european.n.01', 0), 2),
#  (('arrest', 'relative.n.01', 0), 2),
#  (('arrest', 'administrative_district.n.01', 1), 2),
#  (('face', 'migrant.n.01', 1), 2),
#  (('arrest', 'unfortunate.n.01', 1), 2),
#  (('face', 'wound.n.01', 1), 2),
#  (('arrest', 'dish.n.02', 0), 2),
#  (('arrest', 'aid.n.03', 0), 2),
#  (('accuse', 'disorder.n.01', 1), 2),
#  (('arrest', 'central_american.n.01', 1), 2),
#  (('face', 'hindrance.n.01', 0), 2),
#  (('face', 'united_kingdom.n.01', 0), 2),
#  (('indict', 'associate.n.01', 0), 2),
#  (('arrest', 'spacing.n.02', 0), 2),
#  (('charge', 'skilled_worker.n.01', 0), 2),
#  (('face', 'collection.n.01', 0), 2),
#  (('arrest', 'airplane.n.01', 0), 2),
#  (('charge', 'division.n.04', 1), 2),
#  (('accuse', 'israel.n.01', 1), 2),
#  (('arrest', 'nelson.n.01', 0), 2),
#  (('plead', 'pair.n.03', 1), 2),
#  (('accuse', 'administrative_unit.n.01', 0), 2),
#  (('accuse', 'religious_person.n.01', 0), 2),
#  (('convict', 'criminal.n.01', 0), 2),
#  (('arrest', 'ochoa.n.01', 0), 2),
#  (('accuse', 'israel.n.01', 0), 2),
#  (('face', 'slope.n.01', 1), 2),
#  (('face', 'nondepository_financial_institution.n.01', 1), 2),
#  (('charge', 'serviceman.n.01', 0), 2),
#  (('accuse', 'scientist.n.01', 1), 2),
#  (('arrest', 'point.n.06', 0), 2),
#  (('charge', 'crime.n.01', 0), 2),
#  (('convict', 'blair.n.01', 0), 2),
#  (('face', 'blair.n.01', 1), 2),
#  (('sentence', 'miller.n.01', 0), 2),
#  (('arrest', 'legal_document.n.01', 0), 2),
#  (('arrest', 'salem.n.01', 0), 2),
#  (('arrest', 'smith.n.01', 0), 2),
#  (('charge', 'administrative_district.n.01', 1), 2),
#  (('accuse', 'administrative_district.n.01', 1), 2),
#  (('charge', 'body.n.02', 1), 2),
#  (('arrest', 'performer.n.01', 0), 2),
#  (('arrest', 'military_service.n.01', 1), 2),
#  (('arrest', 'european.n.01', 1), 2),
#  (('face', 'administrative_district.n.01', 1), 2),
#  (('arrest', 'london.n.01', 1), 2),
#  (('face', 'arab.n.01', 1), 2),
#  (('face', 'happening.n.01', 0), 2),
#  (('arrest', 'lawyer.n.01', 0), 2),
#  (('arrest', 'china.n.01', 1), 2),
#  (('charge', 'head.n.04', 1), 2),
#  (('charge', 'user.n.01', 1), 2),
#  (('arrest', 'african.n.01', 0), 2),
#  (('charge', 'serviceman.n.01', 1), 2),
#  (('arrest', 'abstraction.n.06', 0), 2),
#  (('face', 'operator.n.02', 1), 2),
#  (('arrest', 'markov.n.01', 0), 2),
#  (('arrest', 'knox.n.01', 0), 2),
#  (('face', 'thoroughfare.n.01', 0), 2),
#  (('face', 'assembly.n.04', 0), 2),
#  (('arrest', 'clergyman.n.01', 0), 2),
#  (('face', 'muhammad.n.01', 1), 2),
#  (('arrest', 'payer.n.01', 0), 2),
#  (('arrest', 'unit.n.03', 1), 2),
#  (('plead', 'attack.n.01', 0), 2),
#  (('face', 'investigation.n.02', 0), 2),
#  (('charge', 'material.n.01', 0), 2),
#  (('accuse', 'hizballah.n.01', 0), 2),
#  (('arrest', 'instigator.n.01', 0), 2),
#  (('arrest', 'day.n.04', 0), 2),
#  (('arrest', 'authority.n.03', 0), 2),
#  (('arrest', 'capture.n.01', 1), 2),
#  (('testify', 'change_of_state.n.01', 1), 2),
#  (('face', 'contestant.n.01', 0), 2),
#  (('plead', 'israel.n.01', 1), 2),
#  (('sentence', 'string_of_words.n.01', 1), 2),
#  (('arrest', 'thomas.n.01', 0), 2),
#  (('face', 'military_action.n.01', 0), 2),
#  (('charge', 'spouse.n.01', 0), 2),
#  (('arrest', 'general_officer.n.01', 0), 2),
#  (('acquit', 'adjudicator.n.01', 1), 2),
#  (('arrest', 'edge_tool.n.01', 0), 2),
#  (('accuse', 'austin.n.01', 1), 2),
#  (('convict', 'radical.n.03', 1), 2),
#  (('arrest', 'adult.n.01', 1), 2),
#  (('face', 'serbia.n.01', 1), 2),
#  (('arrest', 'politician.n.01', 0), 2),
#  (('face', 'juvenile.n.01', 1), 2),
#  (('arrest', 'consumer.n.01', 0), 2),
#  (('arrest', 'soldier.n.01', 1), 2),
#  (('accuse', 'administrative_district.n.01', 0), 2),
#  (('arrest', 'civil_authority.n.01', 0), 2),
#  (('accuse', 'leader.n.01', 1), 2),
#  (('arrest', 'importance.n.01', 1), 2),
#  (('arrest', 'blanket.n.01', 0), 2),
#  (('charge', 'firm.n.01', 0), 2),
#  (('arrest', 'unit.n.05', 0), 2),
#  (('accuse', 'place_of_business.n.01', 1), 2),
#  (('arrest', 'taylor.n.01', 0), 2),
#  (('testify', 'linguist.n.02', 1), 2),
#  (('testify', 'burk.n.01', 1), 2),
#  (('accuse', 'associate.n.01', 0), 2),
#  (('convict', 'common_fraction.n.01', 0), 2),
#  (('plead', 'traveler.n.01', 1), 2),
#  (('testify', 'campbell.n.01', 1), 2),
#  (('accuse', 'large_integer.n.01', 0), 2),
#  (('arrest', 'evidence.n.02', 0), 2),
#  (('charge', 'disorder.n.01', 1), 2),
#  (('arrest', 'unit.n.03', 0), 2),
#  (('arrest', 'lever.n.01', 1), 2),
#  (('accuse', 'influence.n.01', 0), 2),
#  (('arrest', 'motor_vehicle.n.01', 0), 2),
#  (('arrest', 'assistant.n.01', 0), 2),
#  (('face', 'medical_practitioner.n.01', 1), 2),
#  (('face', 'whole.n.01', 1), 2),
#  (('face', 'highway.n.01', 0), 2),
#  (('arrest', 'auditory_communication.n.01', 0), 2),
#  (('accuse', 'arafat.n.01', 0), 2),
#  (('accuse', 'plan_of_action.n.01', 1), 2),
#  (('arrest', 'artist.n.01', 0), 2),
#  (('accuse', 'india.n.01', 1), 2),
#  (('accuse', 'woman.n.01', 1), 2),
#  (('testify', 'group.n.01', 1), 2),
#  (('arrest', 'spokesperson.n.01', 0), 2),
#  (('arrest', 'native.n.01', 0), 2),
#  (('arrest', 'linear_unit.n.01', 1), 2),
#  (('charge', 'woman.n.01', 1), 2),
#  (('arrest', 'robinson.n.01', 0), 2),
#  (('testify', 'psychological_state.n.01', 1), 2),
#  (('face', 'component.n.03', 1), 2),
#  (('face', 'conifer.n.01', 1), 2),
#  (('arrest', 'massachusetts.n.01', 1), 2),
#  (('arrest', 'craftsman.n.03', 0), 2),
#  (('acquit', 'person.n.01', 0), 2),
#  (('face', 'china.n.01', 1), 2),
#  (('arrest', 'destroyer.n.02', 0), 2),
#  (('arrest', 'jackson.n.01', 0), 2),
#  (('face', 'contestant.n.01', 1), 2),
#  (('charge', 'pair.n.03', 0), 2),
#  (('arrest', 'decision.n.01', 0), 2),
#  (('accuse', 'canine.n.02', 0), 2),
#  (('arrest', 'sovereign.n.01', 0), 2),
#  (('charge', 'geological_formation.n.01', 1), 2),
#  (('arrest', 'transgression.n.01', 0), 2),
#  (('accuse', 'steering_system.n.01', 1), 2),
#  (('charge', 'arab.n.01', 0), 1),
#  (('arrest', 'mediator.n.01', 0), 1),
#  (('testify', 'dynasty.n.01', 1), 1),
#  (('testify', 'gathering.n.01', 0), 1),
#  (('testify', 'litigant.n.01', 1), 1),
#  (('testify', 'babar.n.01', 1), 1),
#  (('testify', 'ross.n.01', 1), 1),
#  (('testify', 'scientist.n.01', 1), 1),
#  (('testify', 'greene.n.01', 1), 1),
#  (('plead', 'psychological_state.n.01', 1), 1),
#  (('arrest', 'more.n.01', 1), 1),
#  (('acquit', 'crime.n.01', 0), 1),
#  (('testify', 'richardson.n.01', 1), 1),
#  (('arrest', 'secret_agent.n.01', 0), 1),
#  (('arrest', 'social_group.n.01', 1), 1),
#  (('face', 'happening.n.01', 1), 1),
#  (('face', 'business_relation.n.01', 0), 1),
#  (('accuse', 'specialist.n.02', 1), 1),
#  (('accuse', 'coalition.n.02', 1), 1),
#  (('testify', 'medical_practitioner.n.01', 1), 1),
#  (('arrest', 'drake.n.01', 0), 1),
#  (('face', 'unit.n.03', 1), 1),
#  (('arrest', 'unrighteousness.n.01', 0), 1),
#  (('arrest', 'determination.n.01', 1), 1),
#  (('plead', 'james.n.01', 1), 1),
#  (('testify', 'spouse.n.01', 1), 1),
#  (('arrest', 'james.n.01', 0), 1),
#  (('face', 'chromatic_color.n.01', 1), 1),
#  (('arrest', 'ridge.n.01', 0), 1),
#  (('face', 'attack.n.01', 1), 1),
#  (('face', 'likelihood.n.01', 0), 1),
#  (('face', 'property.n.02', 1), 1),
#  (('sentence', 'person.n.01', 0), 1),
#  (('accuse', 'reformer.n.01', 1), 1),
#  (('face', 'race.n.01', 1), 1),
#  (('face', 'instigator.n.01', 1), 1),
#  (('arrest', 'antony.n.01', 0), 1),
#  (('face', 'idea.n.01', 1), 1),
#  (('arrest', 'youth_subculture.n.01', 0), 1),
#  (('charge', 'amount.n.02', 1), 1),
#  (('face', 'austin.n.01', 1), 1),
#  (('charge', 'social_group.n.01', 1), 1),
#  (('plead', 'control.n.05', 0), 1),
#  (('arrest', 'enclosure.n.01', 0), 1),
#  (('accuse', 'sullivan.n.01', 0), 1),
#  (('arrest', 'body.n.02', 0), 1),
#  (('charge', 'mixture.n.01', 0), 1),
#  (('charge', 'code.n.02', 0), 1),
#  (('charge', 'riley.n.01', 0), 1),
#  (('accuse', 'serviceman.n.01', 1), 1),
#  (('charge', 'acting.n.01', 0), 1),
#  (('face', 'transferred_property.n.01', 0), 1),
#  (('arrest', 'spiritual_being.n.01', 0), 1),
#  (('accuse', 'asian.n.01', 0), 1),
#  (('arrest', 'time.n.03', 0), 1),
#  (('convict', 'external_body_part.n.01', 1), 1),
#  (('accuse', 'thompson.n.01', 1), 1),
#  (('plead', 'woman.n.01', 1), 1),
#  (('arrest', 'shaw.n.01', 0), 1),
#  (('arrest', 'cortes.n.01', 0), 1),
#  (('accuse', 'large_integer.n.01', 1), 1),
#  (('sentence', 'man.n.01', 0), 1),
#  (('charge', 'financier.n.01', 0), 1),
#  (('charge', 'external_body_part.n.01', 1), 1),
#  (('charge', 'punishment.n.01', 0), 1),
#  (('face', 'commercial_enterprise.n.01', 1), 1),
#  (('arrest', 'maker.n.01', 0), 1),
#  (('sentence', 'woman.n.01', 0), 1),
#  (('arrest', 'moody.n.01', 0), 1),
#  (('face', 'script.n.01', 1), 1),
#  (('face', 'aggression.n.03', 0), 1),
#  (('arrest', 'vote.n.02', 0), 1),
#  (('indict', 'large_integer.n.01', 0), 1),
#  (('face', 'rebellion.n.02', 0), 1),
#  (('face', 'influence.n.01', 0), 1),
#  (('arrest', 'slav.n.01', 0), 1),
#  (('accuse', 'mubarak.n.01', 1), 1),
#  (('accuse', 'commoner.n.01', 1), 1),
#  (('arrest', 'crime.n.01', 0), 1),
#  (('face', 'detail.n.01', 1), 1),
#  (('face', 'phenomenon.n.01', 0), 1),
#  (('arrest', 'political_system.n.01', 1), 1),
#  (('face', 'escape.n.01', 1), 1),
#  (('accuse', 'male_offspring.n.01', 0), 1),
#  (('face', 'disputant.n.01', 0), 1),
#  (('face', 'weapon.n.01', 1), 1),
#  (('arrest', 'administrative_district.n.01', 0), 1),
#  (('face', 'felony.n.01', 0), 1),
#  (('arrest', 'boone.n.01', 1), 1),
#  (('arrest', 'agent.n.03', 0), 1),
#  (('arrest', 'definite_quantity.n.01', 1), 1),
#  (('testify', 'martin.n.01', 1), 1),
#  (('arrest', 'religious.n.01', 0), 1),
#  (('arrest', 'confederate_soldier.n.01', 0), 1),
#  (('accuse', 'division.n.04', 1), 1),
#  (('accuse', 'belgrade.n.01', 1), 1),
#  (('accuse', 'west.n.01', 0), 1),
#  (('arrest', 'national.n.01', 1), 1),
#  (('charge', 'stepchild.n.01', 0), 1),
#  (('charge', 'hockey_player.n.01', 0), 1),
#  (('face', 'assistant.n.01', 1), 1),
#  (('accuse', 'time_period.n.01', 1), 1),
#  (('accuse', 'aaron.n.01', 0), 1),
#  (('plead', 'clergyman.n.01', 1), 1),
#  (('indict', 'people.n.01', 0), 1),
#  (('indict', 'adult.n.01', 0), 1),
#  (('arrest', 'warner.n.01', 0), 1),
#  (('arrest', 'evert.n.01', 0), 1),
#  (('arrest', 'size.n.02', 0), 1),
#  (('arrest', 'pauper.n.01', 0), 1),
#  (('arrest', 'peter.n.01', 0), 1),
#  (('plead', 'peter.n.01', 1), 1),
#  (('acquit', 'large_integer.n.01', 0), 1),
#  (('testify', 'craftsman.n.03', 1), 1),
#  (('arrest', 'location.n.01', 0), 1),
#  (('charge', 'herb.n.01', 0), 1),
#  (('face', 'lawyer.n.01', 1), 1),
#  (('arrest', 'walker.n.01', 0), 1),
#  (('arrest', 'father.n.01', 0), 1),
#  (('testify', 'salesperson.n.01', 1), 1),
#  (('arrest', 'attack.n.01', 1), 1),
#  (('charge', 'wound.n.01', 0), 1),
#  (('face', 'amerindian.n.01', 1), 1),
#  (('face', 'effort.n.02', 0), 1),
#  (('face', 'artwork.n.01', 1), 1),
#  (('face', 'polity.n.02', 0), 1),
#  (('face', 'garment.n.01', 0), 1),
#  (('face', 'political_orientation.n.01', 1), 1),
#  (('face', 'experiment.n.02', 0), 1),
#  (('accuse', 'united_kingdom.n.01', 1), 1),
#  (('accuse', 'baghdad.n.01', 0), 1),
#  (('arrest', 'specialist.n.02', 0), 1),
#  (('charge', 'dishonesty.n.01', 1), 1),
#  (('face', 'hale.n.01', 1), 1),
#  (('face', 'bradford.n.01', 1), 1),
#  (('face', 'polymer.n.01', 1), 1),
#  (('arrest', 'scandinavian.n.02', 1), 1),
#  (('accuse', 'military_officer.n.01', 1), 1),
#  (('accuse', 'litigant.n.01', 1), 1),
#  (('accuse', 'religion.n.02', 1), 1),
#  (('arrest', 'bully.n.01', 0), 1),
#  (('testify', 'wilson.n.01', 1), 1),
#  (('face', 'questioning.n.01', 0), 1),
#  (('accuse', 'thinker.n.02', 0), 1),
#  (('arrest', 'precursor.n.02', 1), 1),
#  (('charge', 'lawman.n.01', 1), 1),
#  (('face', 'political_unit.n.01', 0), 1),
#  (('accuse', 'contestant.n.01', 0), 1),
#  (('charge', 'treatment.n.02', 1), 1),
#  (('accuse', 'professional.n.01', 0), 1),
#  (('accuse', 'writ.n.01', 1), 1),
#  (('charge', 'profession.n.01', 0), 1),
#  (('convict', 'crime.n.01', 0), 1),
#  (('face', 'teacher.n.01', 1), 1),
#  (('charge', 'municipality.n.01', 1), 1),
#  (('face', 'maneuver.n.04', 0), 1),
#  (('indict', 'small_indefinite_quantity.n.01', 1), 1),
#  (('charge', 'rank.n.02', 1), 1),
#  (('arrest', 'common_fraction.n.01', 1), 1),
#  (('arrest', 'central_american.n.01', 0), 1),
#  (('arrest', 'presiding_officer.n.01', 0), 1),
#  (('arrest', 'reference_point.n.01', 0), 1),
#  (('arrest', 'large_integer.n.01', 1), 1),
#  (('arrest', 'rosario.n.01', 0), 1),
#  (('indict', 'mauldin.n.01', 0), 1),
#  (('arrest', 'mauldin.n.01', 0), 1),
#  (('charge', 'large_integer.n.01', 0), 1),
#  (('charge', 'hussein.n.01', 0), 1),
#  (('arrest', 'power_tool.n.01', 0), 1),
#  (('charge', 'weekday.n.01', 1), 1),
#  (('arrest', 'administrative_unit.n.01', 0), 1),
#  (('arrest', 'invitation.n.01', 0), 1),
#  (('testify', 'domestic_partner.n.01', 1), 1),
#  (('arrest', 'detroit.n.01', 1), 1),
#  (('sentence', 'situation.n.01', 1), 1),
#  (('charge', 'lewis.n.01', 0), 1),
#  (('arrest', 'lewis.n.01', 0), 1),
#  (('arrest', 'case.n.06', 0), 1),
#  (('face', 'group_action.n.01', 0), 1),
#  (('charge', 'medium_of_exchange.n.01', 0), 1),
#  (('charge', 'professional.n.01', 0), 1),
#  (('testify', 'noncommissioned_officer.n.01', 1), 1),
#  (('arrest', 'relation.n.01', 1), 1),
#  (('face', 'disorder.n.03', 0), 1),
#  (('face', 'person.n.01', 0), 1),
#  (('face', 'armored_vehicle.n.01', 0), 1),
#  (('charge', 'arafat.n.01', 1), 1),
#  (('arrest', 'sitter.n.01', 0), 1),
#  (('arrest', 'insight.n.03', 0), 1),
#  (('face', 'perplexity.n.01', 1), 1),
#  (('face', 'sullivan.n.01', 0), 1),
#  (('arrest', 'object.n.01', 0), 1),
#  (('charge', 'fixed_charge.n.01', 0), 1),
#  (('arrest', 'abraham.n.01', 0), 1),
#  (('face', 'influence.n.01', 1), 1),
#  (('arrest', 'municipality.n.01', 1), 1),
#  (('charge', 'parent.n.01', 1), 1),
#  (('plead', 'unfortunate.n.01', 1), 1),
#  (('arrest', 'compartment.n.01', 0), 1),
#  (('indict', 'person.n.01', 1), 1),
#  (('arrest', 'artistic_movement.n.01', 0), 1),
#  (('arrest', 'root_vegetable.n.01', 0), 1),
#  (('convict', 'profession.n.01', 0), 1),
#  (('accuse', 'capture.n.01', 1), 1),
#  (('plead', 'penalty.n.02', 1), 1),
#  (('charge', 'penalty.n.02', 0), 1),
#  (('arrest', 'inflammation.n.01', 0), 1),
#  (('arrest', 'national.n.01', 0), 1),
#  (('arrest', 'movable_barrier.n.01', 1), 1),
#  (('plead', 'group.n.01', 1), 1),
#  (('face', 'perceiver.n.01', 1), 1),
#  (('accuse', 'lawyer.n.01', 0), 1),
#  (('arrest', 'confusion.n.01', 0), 1),
#  (('face', 'perplexity.n.01', 0), 1),
#  (('acquit', 'pillar_of_islam.n.01', 0), 1),
#  (('plead', 'large_indefinite_quantity.n.01', 1), 1),
#  (('accuse', 'expert.n.01', 1), 1),
#  (('arrest', 'clergyman.n.01', 1), 1),
#  (('accuse', 'abraham.n.01', 0), 1),
#  (('charge', 'felony.n.01', 0), 1),
#  (('arrest', 'imaginary_being.n.01', 0), 1),
#  (('face', 'scott.n.01', 1), 1),
#  (('arrest', 'south_american.n.01', 0), 1),
#  (('charge', 'parent.n.01', 0), 1),
#  (('face', 'meeting.n.01', 0), 1),
#  (('face', 'highjacking.n.01', 0), 1),
#  (('charge', 'evidence.n.02', 1), 1),
#  (('accuse', 'socialism.n.02', 1), 1),
#  (('arrest', 'ending.n.04', 0), 1),
#  (('arrest', 'morrison.n.01', 0), 1),
#  (('arrest', 'inductance_unit.n.01', 0), 1),
#  (('face', 'lawman.n.01', 1), 1),
#  (('face', 'impermanence.n.01', 0), 1),
#  (('face', 'condition.n.01', 1), 1),
#  (('arrest', 'peer.n.01', 0), 1),
#  (('arrest', 'happening.n.01', 1), 1),
#  (('arrest', 'custodian.n.01', 0), 1),
#  (('charge', 'abstraction.n.01', 1), 1),
#  (('charge', 'crime.n.01', 1), 1),
#  (('face', 'control.n.01', 0), 1),
#  (('convict', 'adult.n.01', 0), 1),
#  (('sentence', 'force.n.04', 0), 1),
#  (('arrest', 'wit.n.01', 0), 1),
#  (('accuse', 'johnson.n.01', 0), 1),
#  (('charge', 'writ.n.01', 1), 1),
#  (('arrest', 'allen.n.01', 0), 1),
#  (('arrest', 'happening.n.01', 0), 1),
#  (('charge', 'rate.n.01', 0), 1),
#  (('face', 'arab.n.01', 0), 1),
#  (('charge', 'male.n.02', 0), 1),
#  (('arrest', 'uma.n.01', 1), 1),
#  (('testify', 'hour.n.02', 1), 1),
#  (('arrest', 'deceiver.n.01', 0), 1),
#  (('face', 'jones.n.01', 1), 1),
#  (('arrest', 'official.n.02', 0), 1),
#  (('accuse', 'general_officer.n.01', 1), 1),
#  (('arrest', 'mammal_genus.n.01', 0), 1),
#  (('face', 'religion.n.02', 1), 1),
#  (('convict', 'adjudicator.n.01', 1), 1),
#  (('accuse', 'proceeding.n.01', 1), 1),
#  (('accuse', 'rivera.n.01', 0), 1),
#  (('accuse', 'religion.n.02', 0), 1),
#  (('charge', 'clergyman.n.01', 0), 1),
#  (('arrest', 'collection.n.01', 0), 1),
#  (('arrest', 'italian.n.01', 0), 1),
#  (('face', 'clergyman.n.01', 1), 1),
#  (('accuse', 'religious.n.01', 1), 1),
#  (('accuse', 'spiritual_leader.n.01', 0), 1),
#  (('arrest', 'material.n.01', 1), 1),
#  (('face', 'people.n.01', 1), 1),
#  (('plead', 'trial_period.n.01', 0), 1),
#  (('face', 'killing.n.02', 0), 1),
#  (('arrest', 'pigeon.n.01', 1), 1),
#  (('plead', 'natural_object.n.01', 1), 1),
#  (('arrest', 'kelly.n.01', 0), 1),
#  (('convict', 'european.n.01', 0), 1),
#  (('arrest', 'boone.n.01', 0), 1),
#  (('face', 'marital_status.n.01', 0), 1),
#  (('sentence', 'time_period.n.01', 1), 1),
#  (('arrest', 'draco.n.01', 1), 1),
#  (('face', 'forest.n.02', 1), 1),
#  (('plead', 'thomas.n.01', 1), 1),
#  (('charge', 'thomas.n.01', 0), 1),
#  (('face', 'flow.n.01', 0), 1),
#  (('accuse', 'document.n.01', 1), 1),
#  (('testify', 'gramineous_plant.n.01', 1), 1),
#  (('accuse', 'agent.n.02', 1), 1),
#  (('accuse', 'spectator.n.01', 1), 1),
#  (('arrest', 'franklin.n.01', 0), 1),
#  (('face', 'franklin.n.01', 1), 1),
#  (('charge', 'carmichael.n.01', 0), 1),
#  (('testify', 'male_sibling.n.01', 1), 1),
#  (('face', 'vegetation.n.01', 1), 1),
#  (('charge', 'corridor.n.01', 0), 1),
#  (('charge', 'player.n.01', 0), 1),
#  (('acquit', 'educator.n.01', 1), 1),
#  (('arrest', 'geological_formation.n.01', 0), 1),
#  (('convict', 'more.n.01', 0), 1),
#  (('arrest', 'assurance.n.02', 1), 1),
#  (('charge', 'policeman.n.01', 1), 1),
#  (('arrest', 'african.n.01', 1), 1),
#  (('face', 'quality.n.01', 0), 1),
#  (('accuse', 'administrative_unit.n.01', 1), 1),
#  (('arrest', 'malone.n.01', 0), 1),
#  (('face', 'parent.n.01', 1), 1),
#  (('accuse', 'advocate.n.01', 1), 1),
#  (('accuse', 'politician.n.01', 0), 1),
#  (('face', 'bowie.n.01', 1), 1),
#  (('arrest', 'bowie.n.01', 0), 1),
#  (('face', 'associate.n.01', 0), 1),
#  (('arrest', 'female_offspring.n.01', 0), 1),
#  (('arrest', 'natural_object.n.01', 0), 1),
#  (('plead', 'administrator.n.01', 1), 1),
#  (('face', 'god.n.01', 0), 1),
#  (('arrest', 'russian.n.01', 0), 1),
#  (('face', 'legal_document.n.01', 1), 1),
#  (('face', 'measure.n.02', 0), 1),
#  (('plead', 'harvey.n.01', 1), 1),
#  (('arrest', 'substance.n.01', 0), 1),
#  (('accuse', 'salina.n.01', 0), 1),
#  (('charge', 'worker.n.01', 0), 1),
#  (('face', 'rule.n.01', 0), 1),
#  (('accuse', 'asian.n.01', 1), 1),
#  (('accuse', 'causal_agent.n.01', 1), 1),
#  (('arrest', 'tucker.n.01', 1), 1),
#  (('arrest', 'sense_organ.n.01', 0), 1),
#  (('face', 'movement.n.03', 0), 1),
#  (('indict', 'transgression.n.01', 0), 1),
#  (('accuse', 'gregorian_calendar_month.n.01', 1), 1),
#  (('convict', 'radical.n.03', 0), 1),
#  (('face', 'consequence.n.01', 1), 1),
#  (('arrest', 'kinsman.n.01', 0), 1),
#  (('accuse', 'kinsman.n.01', 0), 1),
#  (('face', 'place_of_business.n.01', 0), 1),
#  (('face', 'unfortunate.n.01', 1), 1),
#  (('convict', 'talbot.n.01', 0), 1),
#  (('testify', 'woman.n.01', 1), 1),
#  (('testify', 'acquaintance.n.03', 1), 1),
#  (('charge', 'garment.n.01', 1), 1),
#  (('face', 'associate.n.01', 1), 1),
#  (('face', 'capture.n.01', 0), 1),
#  (('arrest', 'function.n.01', 0), 1),
#  (('arrest', 'agglomeration.n.01', 0), 1),
#  (('convict', 'juvenile.n.01', 0), 1),
#  (('testify', 'skilled_worker.n.01', 1), 1),
#  (('plead', 'stephen.n.01', 1), 1),
#  (('arrest', 'hartford.n.01', 1), 1),
#  (('accuse', 'activity.n.01', 0), 1),
#  (('arrest', 'upstart.n.02', 0), 1),
#  (('arrest', 'written_communication.n.01', 0), 1),
#  (('arrest', 'group_action.n.01', 1), 1),
#  (('plead', 'law_enforcement_agency.n.01', 1), 1),
#  (('face', 'hess.n.01', 1), 1),
#  (('charge', 'contestant.n.01', 1), 1),
#  (('accuse', 'institution.n.01', 1), 1),
#  (('face', 'taylor.n.01', 1), 1),
#  (('charge', 'omission.n.04', 1), 1),
#  (('charge', 'descendant.n.01', 0), 1),
#  (('arrest', 'matter.n.03', 0), 1),
#  (('arrest', 'bradley.n.01', 0), 1),
#  (('face', 'canine.n.02', 0), 1),
#  (('arrest', 'citizen.n.01', 0), 1),
#  (('face', 'enrollee.n.01', 1), 1),
#  (('accuse', 'attempt.n.01', 1), 1),
#  (('arrest', 'warrior.n.01', 0), 1),
#  (('arrest', 'bison.n.01', 0), 1),
#  (('plead', 'litigant.n.01', 1), 1),
#  (('arrest', 'carroll.n.01', 1), 1),
#  (('accuse', 'work.n.01', 0), 1),
#  (('arrest', 'dias.n.01', 0), 1),
#  (('face', 'job_action.n.01', 0), 1),
#  (('arrest', 'terror.n.04', 0), 1),
#  (('accuse', 'division.n.04', 0), 1),
#  (('accuse', 'china.n.01', 1), 1),
#  (('accuse', 'stranger.n.01', 0), 1),
#  (('arrest', 'control.n.05', 0), 1),
#  (('plead', 'shaw.n.01', 1), 1),
#  (('arrest', 'academician.n.03', 0), 1),
#  (('arrest', 'movable_barrier.n.01', 0), 1),
#  (('accuse', 'movable_barrier.n.01', 1), 1),
#  (('arrest', 'interrogation.n.03', 1), 1),
#  (('accuse', 'pair.n.03', 0), 1),
#  (('arrest', 'pierce.n.01', 1), 1),
#  (('sentence', 'adult.n.01', 0), 1),
#  (('arrest', 'garment.n.01', 1), 1),
#  (('arrest', 'advocate.n.01', 0), 1),
#  (('arrest', 'state.n.02', 0), 1),
#  (('face', 'change.n.03', 0), 1),
#  (('arrest', 'driver.n.01', 0), 1),
#  (('arrest', 'natural_elevation.n.01', 0), 1),
#  (('indict', 'serviceman.n.01', 0), 1),
#  (('charge', 'assertion.n.01', 1), 1),
#  (('charge', 'municipality.n.01', 0), 1),
#  (('arrest', 'davys.n.01', 0), 1),
#  (('accuse', 'good_person.n.01', 0), 1),
#  (('arrest', 'sanchez.n.01', 0), 1),
#  (('face', 'document.n.01', 0), 1),
#  (('face', 'davys.n.01', 1), 1),
#  (('charge', 'davys.n.01', 0), 1),
#  (('plead', 'hawkins.n.01', 1), 1),
#  (('arrest', 'salerno.n.01', 0), 1),
#  (('arrest', 'lawman.n.01', 0), 1),
#  (('charge', 'religious_person.n.01', 0), 1),
#  (('accuse', 'germany.n.01', 1), 1),
#  (('charge', 'social_control.n.01', 1), 1),
#  (('arrest', 'photographer.n.01', 0), 1),
#  (('arrest', 'athlete.n.01', 0), 1),
#  (('testify', 'migrant.n.01', 1), 1),
#  (('charge', 'lee.n.01', 1), 1),
#  (('charge', 'male.n.02', 1), 1),
#  (('indict', 'american.n.01', 1), 1),
#  (('face', 'hour.n.02', 1), 1),
#  (('face', 'susceptibility.n.01', 0), 1),
#  (('arrest', 'thoroughfare.n.01', 0), 1),
#  (('arrest', 'mercantile_establishment.n.01', 0), 1),
#  (('accuse', 'danger.n.03', 1), 1),
#  (('accuse', 'army_unit.n.01', 0), 1),
#  (('indict', 'division.n.04', 1), 1),
#  (('accuse', 'washington.n.01', 1), 1),
#  (('arrest', 'commissioned_military_officer.n.01', 0), 1),
#  (('charge', 'galicia.n.01', 0), 1),
#  (('arrest', 'concern.n.04', 0), 1),
#  (('arrest', 'structure.n.01', 0), 1),
#  (('arrest', 'commoner.n.01', 1), 1),
#  (('face', 'bethlehem.n.01', 1), 1),
#  (('face', 'point.n.02', 0), 1),
#  (('face', 'opinion.n.01', 0), 1),
#  (('accuse', 'lashkar-e-taiba.n.01', 0), 1),
#  (('arrest', 'extremity.n.05', 1), 1),
#  (('charge', 'presiding_officer.n.01', 0), 1),
#  (('face', 'agreement.n.01', 0), 1),
#  (('arrest', 'punishment.n.01', 0), 1),
#  (('face', 'dicot_genus.n.01', 1), 1),
#  (('arrest', 'end.n.02', 1), 1),
#  (('arrest', 'evans.n.01', 0), 1),
#  (('charge', 'felony.n.01', 1), 1),
#  (('arrest', 'trader.n.01', 0), 1),
#  (('face', 'arafat.n.01', 1), 1),
#  (('face', 'time_unit.n.01', 0), 1),
#  (('accuse', 'accusation.n.01', 0), 1),
#  (('arrest', 'common_fraction.n.01', 0), 1),
#  (('arrest', 'israel.n.01', 1), 1),
#  (('face', 'pilgrim.n.03', 1), 1),
#  (('face', 'mecca.n.01', 0), 1),
#  (('arrest', 'motion.n.06', 1), 1),
#  (('arrest', 'approach.n.01', 1), 1),
#  (('face', 'protective_covering.n.01', 1), 1),
#  (('testify', 'sullivan.n.01', 1), 1),
#  (('arrest', 'beggar.n.01', 0), 1),
#  (('arrest', 'material.n.01', 0), 1),
#  (('face', 'administrative_district.n.01', 0), 1),
#  (('accuse', 'friend.n.01', 1), 1),
#  (('indict', 'arab.n.01', 0), 1),
#  (('face', 'season.n.02', 1), 1),
#  (('arrest', 'powell.n.01', 0), 1),
#  (('arrest', 'priest.n.01', 0), 1),
#  (('face', 'evidence.n.02', 1), 1),
#  (('arrest', 'belief.n.01', 1), 1),
#  (('indict', 'control.n.01', 1), 1),
#  (('arrest', 'attack.n.01', 0), 1),
#  (('face', 'part.n.01', 1), 1),
#  (('face', 'root_vegetable.n.01', 1), 1),
#  (('testify', 'chang_jiang.n.01', 1), 1),
#  (('charge', 'unit.n.03', 1), 1),
#  (('charge', 'change.n.01', 0), 1),
#  (('plead', 'migrant.n.01', 1), 1),
#  (('arrest', 'carter.n.01', 0), 1),
#  (('accuse', 'unit.n.03', 1), 1),
#  (('arrest', 'whole.n.01', 0), 1),
#  (('face', 'emotion.n.01', 0), 1),
#  (('accuse', 'organ.n.01', 0), 1),
#  (('testify', 'digit.n.01', 0), 1),
#  (('testify', 'carroll.n.01', 1), 1),
#  (('testify', 'soldier.n.01', 1), 1),
#  (('face', 'narrowing.n.01', 0), 1),
#  (('face', 'slav.n.01', 1), 1),
#  (('indict', 'organization.n.01', 1), 1),
#  (('face', 'dust.n.01', 0), 1),
#  (('arrest', 'money.n.03', 0), 1),
#  (('charge', 'person.n.01', 1), 1),
#  (('arrest', 'animal.n.01', 0), 1),
#  (('face', 'robinson.n.01', 1), 1),
#  (('accuse', 'kremlin.n.01', 0), 1),
#  (('charge', 'robinson.n.01', 0), 1),
#  (('face', 'large_integer.n.01', 0), 1),
#  (('face', 'institution.n.01', 1), 1),
#  (('face', 'disease.n.01', 1), 1),
#  (('plead', 'large_integer.n.01', 1), 1),
#  (('arrest', 'herb.n.01', 0), 1),
#  (('face', 'patrick.n.01', 1), 1),
#  (('arrest', 'entertainment.n.01', 0), 1),
#  (('accuse', 'romance.n.03', 1), 1),
#  (('accuse', 'slav.n.01', 0), 1),
#  (('indict', 'adult.n.01', 1), 1),
#  (('face', 'sovereign.n.01', 1), 1),
#  (('arrest', 'priesthood.n.01', 1), 1),
#  (('arrest', 'volunteer.n.02', 0), 1),
#  (('plead', 'guthrie.n.01', 1), 1),
#  (('indict', 'group.n.01', 0), 1),
#  (('arrest', 'prostitute.n.01', 0), 1),
#  (('testify', 'smith.n.01', 1), 1),
#  (('charge', 'excavation.n.03', 0), 1),
#  (('charge', 'hart.n.01', 0), 1),
#  (('arrest', 'hart.n.01', 0), 1),
#  (('charge', 'fremont.n.01', 0), 1),
#  (('arrest', 'disagreement.n.03', 1), 1),
#  (('arrest', 'organization.n.01', 0), 1),
#  (('face', 'israel.n.01', 0), 1),
#  (('face', 'choice.n.02', 0), 1),
#  (('testify', 'communicator.n.01', 1), 1),
#  (('face', 'social_group.n.01', 1), 1),
#  (('face', 'place_of_business.n.01', 1), 1),
#  (('charge', 'workman.n.01', 1), 1),
#  (('accuse', 'muslim.n.01', 0), 1),
#  (('accuse', 'canine.n.02', 1), 1),
#  (('accuse', 'legislature.n.01', 0), 1),
#  (('arrest', 'agent.n.02', 0), 1),
#  (('face', 'time.n.05', 0), 1),
#  (('plead', 'murray.n.01', 1), 1),
#  (('testify', 'lawman.n.01', 1), 1),
#  (('charge', 'israel.n.01', 1), 1),
#  (('face', 'allen.n.01', 1), 1),
#  (('face', 'group.n.01', 0), 1),
#  (('plead', 'lewis.n.01', 1), 1),
#  (('accuse', 'political_unit.n.01', 1), 1),
#  (('testify', 'aid.n.03', 1), 1),
#  (('accuse', 'extremity.n.05', 0), 1),
#  (('plead', 'criminal.n.01', 1), 1),
#  (('plead', 'financial_condition.n.01', 0), 1),
#  (('accuse', 'grocery_store.n.01', 1), 1),
#  (('accuse', 'representation.n.02', 1), 1),
#  (('face', 'writ.n.01', 0), 1),
#  (('arrest', 'military_service.n.01', 0), 1),
#  (('face', 'mixture.n.01', 0), 1),
#  (('charge', 'citizen.n.01', 0), 1),
#  (('accuse', 'absentee.n.01', 1), 1),
#  (('accuse', 'diplomatic_building.n.01', 0), 1),
#  (('indict', 'polity.n.02', 1), 1),
#  (('face', 'illness.n.01', 0), 1),
#  (('face', 'separation.n.01', 0), 1),
#  (('charge', 'general_officer.n.01', 0), 1),
#  (('accuse', 'lover.n.01', 1), 1),
#  (('indict', 'large_integer.n.01', 1), 1),
#  (('arrest', 'operator.n.02', 1), 1),
#  (('face', 'crime.n.01', 1), 1),
#  (('face', 'case.n.06', 1), 1),
#  ...]

# %%
for root, args in generalized_terms.items():
    print(f"{root}\t{' '.join(args)}")
# Out:
# law_enforcement_agency.n.01	police dea fbi
# political_unit.n.01	pakistan europe nato syria bengal belgium zagreb spain iran country eritrea iraq lebanon yugoslavia
# person.n.01	innocent killer worker leader relative fugitive engineer observer protester advocate friend african expert follower inhabitant neighbor homosexual national adult dissident fighter suspect user blogger lover white juvenile
# skilled_worker.n.01	technician pressman official electrician undertaker hunter editor
# causal_agent.n.01	someone somebody individual person agent
# control.n.01	authority
# arab.n.01	saudi bedouin palestinian
# body.n.02	university jury
# andersen.n.01	andersen
# institution.n.01	company
# assembly.n.04	tribunal court
# attack.n.01	charge bombing
# mediator.n.01	matchmaker
# associate.n.01	colleague member participant
# criminal.n.01	rioter bootlegger trafficker abuser hijacker murderer racketeer dealer flasher thief violator stoner felon troublemaker abductor offender smuggler attacker rapist pimp plotter shoplifter criminal perpetrator mobster pedophile predator
# group.n.01	people
# serviceman.n.01	officer marine veteran
# dynasty.n.01	york
# gathering.n.01	community crowd meeting
# danger.n.03	risk threat
# litigant.n.01	defendant
# lawyer.n.01	prosecutor
# babar.n.01	babar
# digit.n.01	iii one seven ii eight five two nine four six three
# force.n.04	military men
# adult.n.01	woman man
# abstraction.n.06	group
# ross.n.01	ross
# scientist.n.01	investigator psychologist
# male.n.02	boy
# string_of_words.n.01	sentence
# greene.n.01	greene
# pair.n.03	couple
# small_indefinite_quantity.n.01	handful
# adjudicator.n.01	judge
# policeman.n.01	gendarme detective
# social_control.n.01	penalty enforcement discrimination punishment
# psychological_state.n.01	morale
# social_event.n.01	contest
# reformer.n.01	militant insurgent activist
# professional.n.01	attorney practitioner critic lawyer
# spouse.n.01	husband wife
# approval.n.04	sanction
# more.n.01	more
# crime.n.01	scam violation intimidation killing murder fraud smuggling assault felony kidnapping
# perceiver.n.01	spectator witness
# richardson.n.01	richardson
# worker.n.01	employee
# large_integer.n.01	24 ten 28 thousand hundred 29 18 14 10 12 15 tenner 20 30 22 11 dozen
# secret_agent.n.01	spy
# recognizance.n.01	bail
# social_group.n.01	organization minority
# happening.n.01	case fate
# teacher.n.01	demonstrator
# activity.n.01	attempt acting work
# attempt.n.01	struggle trial
# migrant.n.01	settler immigrant
# business_relation.n.01	competition
# army_unit.n.01	division troop squad
# division.n.04	branch department
# male_offspring.n.01	son
# specialist.n.02	psychiatrist
# jones.n.01	jones
# time_unit.n.01	day hour second minute
# unfortunate.n.01	victim homeless survivor prisoner
# coalition.n.02	alliance
# organization.n.01	party union personnel institution
# medical_practitioner.n.01	doctor physician
# drake.n.01	drake
# unit.n.03	family team
# work.n.01	service
# golfer.n.01	hacker
# enrollee.n.01	student
# unrighteousness.n.01	sin
# performer.n.01	actor dancer
# determination.n.01	identification
# james.n.01	james
# chromatic_color.n.01	brown green
# ridge.n.01	reef
# santiago_de_los_caballeros.n.01	santiago
# likelihood.n.01	odds
# simpson.n.01	simpson
# garment.n.01	suit
# instrumentality.n.03	medium
# williams.n.01	williams
# lawman.n.01	sheriff deputy patrolman marshal policeman warden
# polity.n.02	government
# grandparent.n.01	grandfather
# property.n.02	way
# radical.n.03	extremist terrorist
# thinker.n.02	organizer
# jewel.n.01	pearl
# race.n.01	campaign
# set.n.01	pair
# murderer.n.01	gunman assassin
# situation.n.01	thing challenge
# act.n.02	stay action
# power.n.01	control
# function.n.01	operator
# instigator.n.01	ringleader
# difficulty.n.03	problem
# case.n.01	time
# antony.n.01	anthony
# idea.n.01	plan
# action.n.01	resistance opposition
# youth_subculture.n.01	bikers
# example.n.01	sample
# content.n.05	issue
# amount.n.02	number
# austin.n.01	austin
# control.n.05	possession
# enclosure.n.01	chamber
# sullivan.n.01	sullivan
# penetration.n.01	raid
# mixture.n.01	suspension
# municipality.n.01	city
# proceeding.n.01	hearing lawsuit
# code.n.02	morse
# place_of_business.n.01	office
# riley.n.01	riley
# acting.n.01	skit
# natural_virtue.n.01	justice
# juvenile.n.01	teen youngster teenager youth kid child
# transferred_property.n.01	loss
# spiritual_being.n.01	angel
# asian.n.01	korean pakistani israeli iranian indonesian iraqi
# time.n.03	while
# external_body_part.n.01	face
# traveler.n.01	visitor noncitizen rider passenger alien courier migrant transient
# thompson.n.01	thompson
# woman.n.01	girl ex-wife prostitute
# shaw.n.01	shaw
# joseph.n.01	joseph
# cortes.n.01	cortez
# politician.n.02	chiluba president vargas diplomat putin republican bush
# man.n.01	bey ex-husband guy
# inhabitant.n.01	resident marcher occupant
# financier.n.01	banker
# punishment.n.01	imprisonment
# commercial_enterprise.n.01	industry
# physical_phenomenon.n.01	pressure
# maker.n.01	producer
# parent.n.01	mother father
# inquiry.n.01	investigation
# protestant.n.01	fundamentalist
# moody.n.01	moody
# script.n.01	libretto
# word.n.01	term
# extremum.n.02	maximum minimum
# aggression.n.03	violence
# legal_document.n.01	affidavit arraignment bill indictment
# administrator.n.01	director executive
# trainer.n.01	coach
# association.n.01	gang
# slav.n.01	croat serb
# vote.n.02	election
# georgia.n.01	georgia
# rebellion.n.02	insurgency
# influence.n.01	force
# insufficiency.n.03	deficit shortfall
# movable_barrier.n.01	gate door
# mubarak.n.01	mubarak
# yankee.n.01	federal
# proportion.n.01	percentage percent
# commoner.n.01	nobody
# genitor.n.01	parent
# detail.n.01	respect
# phenomenon.n.01	consequence
# political_system.n.01	republic
# escape.n.01	lam
# disputant.n.01	accuser
# capture.n.01	arrest
# case.n.06	client
# weapon.n.01	gun
# administrative_district.n.01	state
# felony.n.01	theft
# boone.n.01	boone
# agent.n.03	drug
# being.n.01	life
# structure.n.01	storey building
# businessperson.n.01	businessman accountant broker merchant entrepreneur
# definite_quantity.n.01	unit
# workman.n.01	mover laborer
# attraction.n.01	bond
# defender.n.01	guard bodyguard
# father_figure.n.01	stepfather
# cord.n.01	string
# martin.n.01	martin
# religious.n.01	nun monk
# johnson.n.01	johnson
# confederate_soldier.n.01	rebel
# disapproval.n.02	condemnation criticism
# european.n.01	frank albanian german briton
# belgrade.n.01	belgrade
# west.n.01	west
# national.n.01	citizen
# writ.n.01	warrant
# drinker.n.02	drunk
# stepchild.n.01	stepson
# friend.n.01	roommate girlfriend
# hockey_player.n.01	goalie
# assistant.n.01	accomplice
# time_period.n.01	weekend week night morning month season year
# relative.n.01	sibling cousin
# aaron.n.01	aaron
# clergyman.n.01	minister cleric priest
# people.n.01	dead public
# warner.n.01	warner
# evert.n.01	evert
# size.n.02	tall
# pauper.n.01	beggar
# peter.n.01	peter
# wound.n.01	gash
# number.n.02	count
# dish.n.02	curry
# craftsman.n.03	mechanic potter
# location.n.01	there
# herb.n.01	alexander
# aid.n.03	grant
# disorder.n.01	complaint
# central_american.n.01	mexican
# walker.n.01	walker
# father.n.01	papa
# salesperson.n.01	salesman
# hindrance.n.01	obstacle
# united_kingdom.n.01	britain
# amerindian.n.01	indian
# effort.n.02	difficulty
# accusation.n.01	allegation recrimination
# leader.n.01	lawmaker trainer imam politician chief
# artwork.n.01	illustration
# linear_unit.n.01	in mile yard
# political_orientation.n.01	democracy
# experiment.n.02	test
# baghdad.n.01	baghdad
# maltreatment.n.01	persecution
# spacing.n.02	distance
# dishonesty.n.01	corruption
# hale.n.01	hale
# bradford.n.01	bradford
# polymer.n.01	dna
# collection.n.01	data backlog set
# scandinavian.n.02	swedish
# airplane.n.01	bomber
# israel.n.01	israel
# military_officer.n.01	commander aide
# religion.n.02	church
# bully.n.01	skinhead
# nelson.n.01	nelson
# wilson.n.01	wilson
# administrative_unit.n.01	council agency commission
# questioning.n.01	question
# religious_person.n.01	christian muslim
# precursor.n.02	predecessor
# contestant.n.01	player challenger opponent
# evaluation.n.02	score
# ochoa.n.01	ochoa
# slope.n.01	bank
# nondepository_financial_institution.n.01	brokerage
# penalty.n.02	retribution fine
# treatment.n.02	dealing
# enlisted_person.n.01	soldier
# point.n.06	moment deadline
# profession.n.01	businessmen
# blair.n.01	blair
# miller.n.01	miller
# maneuver.n.04	measure
# rank.n.02	first
# common_fraction.n.01	third one-third
# salem.n.01	salem
# presiding_officer.n.01	chairman
# smith.n.01	smith
# reference_point.n.01	target
# rosario.n.01	rosario
# mauldin.n.01	mauldin
# hussein.n.01	husain
# power_tool.n.01	sander
# weekday.n.01	saturday tuesday thursday friday monday
# invitation.n.01	summons
# domestic_partner.n.01	partner spouse
# detroit.n.01	detroit
# operator.n.02	driver
# businessman.n.01	owner
# lewis.n.01	lewis
# military_service.n.01	army
# group_action.n.01	coup conflict
# medium_of_exchange.n.01	money
# noncommissioned_officer.n.01	sergeant
# relation.n.01	portion
# disorder.n.03	rioting
# armored_vehicle.n.01	tank
# arafat.n.01	arafat
# potential.n.01	prospect
# fury.n.01	wrath
# sitter.n.01	sitter
# london.n.01	london
# insight.n.03	breakthrough
# perplexity.n.01	dilemma
# object.n.01	web
# fixed_charge.n.01	fee
# abraham.n.01	ibrahim
# surrender.n.03	extradition
# compartment.n.01	cell
# artistic_movement.n.01	van
# root_vegetable.n.01	murphy
# china.n.01	china
# head.n.04	administrator secretary
# inflammation.n.01	founder
# user.n.01	consumer
# male_sibling.n.01	brother
# illustration.n.01	figure
# category.n.02	kind sort
# confusion.n.01	chaos
# pillar_of_islam.n.01	salah
# large_indefinite_quantity.n.01	peck
# expert.n.01	commentator
# imaginary_being.n.01	monster
# scott.n.01	scott
# african.n.01	algerian kenyan
# legal_action.n.01	prosecution
# south_american.n.01	colombian
# state.n.02	revocation situation
# meeting.n.01	conference
# highjacking.n.01	piracy
# evidence.n.02	record
# socialism.n.02	international
# ending.n.04	stop
# morrison.n.01	morrison
# inductance_unit.n.01	henry
# impermanence.n.01	mortality
# condition.n.01	need
# peer.n.01	successor
# markov.n.01	markoff
# custodian.n.01	janitor
# abstraction.n.01	right
# lover.n.01	boyfriend
# knox.n.01	knox
# writing.n.02	document
# wit.n.01	cartoon
# situation.n.03	crisis impasse
# allen.n.01	allen
# rate.n.01	speed
# management.n.01	administration
# thoroughfare.n.01	street
# uma.n.01	uma
# hour.n.02	none
# deceiver.n.01	figurehead
# region.n.01	county
# muhammad.n.01	muhammad
# payer.n.01	tenant
# official.n.02	dispatcher
# general_officer.n.01	general
# mammal_genus.n.01	bos
# investigation.n.02	scrutiny
# rivera.n.01	rivera
# material.n.01	paper
# hizballah.n.01	hezbollah
# italian.n.01	roman
# spiritual_leader.n.01	rabbi
# trial_period.n.01	probation
# killing.n.02	homicide
# day.n.04	afternoon
# pigeon.n.01	dove
# natural_object.n.01	stone body
# authority.n.03	consultant adviser
# kelly.n.01	kelly
# marital_status.n.01	marriage
# change_of_state.n.01	passage
# draco.n.01	draco
# forest.n.02	silva
# thomas.n.01	thomas
# flow.n.01	runoff
# document.n.01	report
# gramineous_plant.n.01	reed
# partition.n.01	wall
# negotiator.n.01	representative
# agent.n.02	operative
# spectator.n.01	eyewitness bystander
# franklin.n.01	franklin
# carmichael.n.01	carmichael
# vegetation.n.01	brush
# military_action.n.01	blockade battle
# corridor.n.01	hall
# player.n.01	golfer
# educator.n.01	teacher
# geological_formation.n.01	beach
# assurance.n.02	vow
# edge_tool.n.01	sickle
# serbia.n.01	serbia
# quality.n.01	uncertainty
# malone.n.01	malone
# politician.n.01	governor
# advocate.n.01	supporter
# extent.n.02	range
# bowie.n.01	bowie
# female_offspring.n.01	daughter
# god.n.01	god
# russian.n.01	chechen
# measure.n.02	probability
# consumer.n.01	customer
# harvey.n.01	harvey
# substance.n.01	material
# salina.n.01	salina
# rule.n.01	restriction
# soldier.n.01	peacekeeper trooper
# tucker.n.01	tucker
# sense_organ.n.01	eye
# movement.n.03	backlash
# transgression.n.01	crime
# gregorian_calendar_month.n.01	november
# civil_authority.n.01	mayor
# consequence.n.01	wake
# kinsman.n.01	nephew
# importance.n.01	significance
# blanket.n.01	afghan
# firm.n.01	corporation
# unit.n.05	radical
# talbot.n.01	talbot
# acquaintance.n.03	classmate
# taylor.n.01	taylor
# agglomeration.n.01	bunch
# linguist.n.02	translator
# burk.n.01	burk
# stephen.n.01	stephen
# hartford.n.01	hartford
# upstart.n.02	junior
# written_communication.n.01	print
# hess.n.01	hess
# omission.n.04	exception
# descendant.n.01	scion
# matter.n.03	substance
# bradley.n.01	bradley
# canine.n.02	fox
# campbell.n.01	campbell
# citizen.n.01	freeman civilian
# warrior.n.01	guerrilla
# bison.n.01	buffalo
# carroll.n.01	carroll
# dias.n.01	diaz
# job_action.n.01	strike
# terror.n.04	terrorism
# lever.n.01	trigger
# stranger.n.01	outsider
# academician.n.03	professor
# muslim.n.01	sunni
# interrogation.n.03	interview
# pierce.n.01	pierce
# motor_vehicle.n.01	car
# change.n.03	demotion
# driver.n.01	cabby racer
# natural_elevation.n.01	hill
# assertion.n.01	claim
# davys.n.01	davis
# good_person.n.01	benefactor
# sanchez.n.01	sanchez
# hawkins.n.01	hawkins
# salerno.n.01	salerno
# whole.n.01	complex
# highway.n.01	interstate
# germany.n.01	germany
# photographer.n.01	cameraman
# athlete.n.01	striker
# lee.n.01	lee
# auditory_communication.n.01	music
# american.n.01	californian
# susceptibility.n.01	liability
# pain.n.01	burn
# mercantile_establishment.n.01	store
# western_malayo-polynesian.n.01	philippine
# mitchell.n.01	mitchell
# information.n.02	fact
# plan_of_action.n.01	policy
# washington.n.01	washington
# commissioned_military_officer.n.01	major
# semite.n.01	arab
# galicia.n.01	galicia
# artist.n.01	photographer
# concern.n.04	burden
# bethlehem.n.01	bethlehem
# point.n.02	place
# opinion.n.01	judgment
# india.n.01	india
# lashkar-e-taiba.n.01	lashkar-e-taiba
# extremity.n.05	hand
# agreement.n.01	conspiracy
# dicot_genus.n.01	olea
# end.n.02	last
# evans.n.01	evans
# trader.n.01	mercer
# pilgrim.n.03	haji
# mecca.n.01	mecca
# motion.n.06	rush
# approach.n.01	avenue
# protective_covering.n.01	cowling
# beggar.n.01	panhandler
# spokesperson.n.01	spokesman
# season.n.02	fall
# powell.n.01	powell
# priest.n.01	bishop
# belief.n.01	opinion
# part.n.01	remainder
# banishment.n.02	deportation
# chang_jiang.n.01	chang
# change.n.01	death
# native.n.01	russian
# carter.n.01	carter
# emotion.n.01	fear
# organ.n.01	wing
# narrowing.n.01	bottleneck
# dust.n.01	fallout
# money.n.03	sterling
# animal.n.01	male
# robinson.n.01	robinson
# kremlin.n.01	kremlin
# disease.n.01	blackwater
# patrick.n.01	patrick
# entertainment.n.01	show
# romance.n.03	french
# sovereign.n.01	king
# priesthood.n.01	ministry
# volunteer.n.02	vigilante
# guthrie.n.01	guthrie
# prostitute.n.01	hustler
# component.n.03	addition
# conifer.n.01	pine
# massachusetts.n.01	massachusetts
# excavation.n.03	well
# hart.n.01	hart
# fremont.n.01	fremont
# disagreement.n.03	dispute
# choice.n.02	decision
# communicator.n.01	reporter
# legislature.n.01	congress
# time.n.05	future
# destroyer.n.02	vandal
# jackson.n.01	jackson
# murray.n.01	murray
# financial_condition.n.01	poverty
# grocery_store.n.01	supermarket
# representation.n.02	photograph
# absentee.n.01	exile
# diplomatic_building.n.01	embassy
# illness.n.01	collapse
# separation.n.01	isolation
# decision.n.01	move
# limit.n.06	cutoff
# collins.n.01	collins
# metallic_element.n.01	nickel
# signaler.n.01	ringer
# metric_linear_unit.n.01	meter
# trench.n.03	furrow
# orr.n.01	orr
# police.n.01	posse
# clark.n.01	clark
# steering_system.n.01	helm
# rustic.n.01	woodman

# %%
# Greedy algorithm to match args with most frequent synsets across all args

def score_synset(synset_name, cur_cnt):
    # Only consider counts below `cur_cnt`, to align with the greedy nature of the approach
    return sum(cnt for _, cnt in inv_synset_index[synset_name] if cnt <= cur_cnt)

# First pass: build inverted index
inv_synset_index = collections.defaultdict(set)
for arg, cnt in common_args.most_common():
    if cnt >= 5:
        synsets = wn.synsets(arg, pos=wn.NOUN)
        for synset in synsets:
            parent_synsets = [y.name() for y in synset.hypernyms()]
            inv_synset_index[synset.name()].add((arg, cnt))
            for parent_synset in parent_synsets:
                inv_synset_index[parent_synset].add((arg, cnt))
        
# Second pass: assign args to synsets in a greedy manner
arg_to_synset = {}
for arg, cur_cnt in common_args.most_common(): 
    if arg not in arg_to_synset:
        synsets = wn.synsets(arg, pos=wn.NOUN)
        cand_synsets = []
        for synset in synsets:
            cand_synsets.append((score_synset(synset.name(), cur_cnt), 1, synset.name()))
            for parent_synset in synset.hypernyms():
                cand_synsets.append((score_synset(parent_synset.name(), cur_cnt), 0, parent_synset.name()))
        cand_synsets = list(set(cand_synsets))
        _, _, best_synset_name = max(cand_synsets)
        # Assign less-or-equal frequent args' synset to `best_synset_name`
        for lf_arg, cnt in inv_synset_index[best_synset_name]:
            if cnt <= cur_cnt:
                arg_to_synset[lf_arg] = best_synset_name
    # print(f'{arg} (cnt = {cur_cnt}) -> {arg_to_synset[arg]}')

# %%
{arg: (cnt, arg_to_synset[arg]) for arg, cnt in common_args.most_common(10)}
# Out:
# {'police': (1128, 'force.n.04'),
#  'suspect': (576, 'person.n.01'),
#  'people': (226, 'group.n.01'),
#  'authority': (162, 'person.n.01'),
#  'man': (138, 'group.n.01'),
#  'charge': (132, 'mission.n.03'),
#  'men': (128, 'group.n.01'),
#  'officer': (94, 'official.n.01'),
#  'prosecutor': (88, 'official.n.01'),
#  'member': (83, 'unit.n.03')}

# %%
for arg, count in common_args.most_common():
    if arg[1] != "illness.n.01":
        continue
    print(f"{arg}\t{count:,}")

# %%
generalized_terms['asian.n.01']
# Out:
# {'indonesian', 'iranian', 'iraqi', 'israeli', 'korean', 'pakistani'}

# %%
for i in wn.synsets('state'):
    print(i, i.definition(), i.hypernyms(), i.root_hypernyms())
# Out:
# Synset('state.n.01') the territory occupied by one of the constituent administrative districts of a nation [Synset('administrative_district.n.01')] [Synset('entity.n.01')]
# Synset('state.n.02') the way something is with respect to its main attributes [Synset('attribute.n.02')] [Synset('entity.n.01')]
# Synset('state.n.03') the group of people comprising the government of a sovereign state [Synset('government.n.01')] [Synset('entity.n.01')]
# Synset('state.n.04') a politically organized body of people under a single government [Synset('political_unit.n.01')] [Synset('entity.n.01')]
# Synset('state_of_matter.n.01') (chemistry) the three traditional states of matter are solids (fixed shape and volume) and liquids (fixed volume and shaped by the container) and gases (filling the container) [Synset('chemical_phenomenon.n.01')] [Synset('entity.n.01')]
# Synset('state.n.06') a state of depression or agitation [Synset('emotional_state.n.01')] [Synset('entity.n.01')]
# Synset('country.n.02') the territory occupied by a nation [Synset('administrative_district.n.01')] [Synset('entity.n.01')]
# Synset('department_of_state.n.01') the federal department in the United States that sets and maintains foreign policies [Synset('executive_department.n.01')] [Synset('entity.n.01')]
# Synset('state.v.01') express in words [Synset('express.v.02')] [Synset('express.v.02')]
# Synset('submit.v.02') put before [Synset('propose.v.01')] [Synset('express.v.02')]
# Synset('express.v.04') indicate through a symbol, formula, etc. [Synset('denote.v.02')] [Synset('mean.v.03')]

# %% [markdown]
# ---
